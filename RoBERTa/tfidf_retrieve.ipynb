# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Prepare Referece files using TFIDF for retrieving attributes

# %%
# %cd "/content/drive/MyDrive/riya"
# Out:
# /content/drive/.shortcut-targets-by-id/1TCvtUjcTYKWgalUeZbJk_aFhLp1aLjr6/riya

# %%
import pandas as pd
from tqdm import tqdm, trange
import numpy as np
import time
import torch
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
def read_file(path):
    with open(path) as fp:
        lines = fp.read().splitlines()
    return lines

# %%
def clean_text(text):
    return text.replace("<POS>","").replace("<NEG>","").replace("<CON_START>","").replace("<START>","").replace("<END>","").strip()

# %%
train0_org = read_file("/content/drive/MyDrive/riya/data/yelp/sentiment.train.0") # Training data of negative sentiment
train1_org = read_file("/content/drive/MyDrive/riya/data/yelp/sentiment.train.1") # Training data of positive sentiment
ref0_processed = read_file("/content/drive/MyDrive/riya/data/yelp/processed_files_with_bert_with_best_head/reference_0.txt") # Reference data for delete_generate model
ref1_processed = read_file("/content/drive/MyDrive/riya/data/yelp/processed_files_with_bert_with_best_head/reference_1.txt") # Reference data for delete_generate model
ref0_org = read_file("/content/drive/MyDrive/riya/data/yelp/reference.0") # Original Refrence_0 data
ref1_org = read_file("/content/drive/MyDrive/riya/data/yelp/reference.1") # Original Refrence_1 data
train0_processed = read_file("/content/drive/MyDrive/riya/data/yelp/processed_files_with_bert_with_best_head/delete_retrieve_edit_model/sentiment_train_0_all_attrs.txt") # training data with content and attributes seperation
train1_processed = read_file("/content/drive/MyDrive/riya/data/yelp/processed_files_with_bert_with_best_head/delete_retrieve_edit_model/sentiment_train_1_all_attrs.txt") # training data with content and attributes seperation

# %%
# Get the Original Reference Sentence
ref0_org = [x.split("\t")[0] for x in ref0_org]
ref1_org = [x.split("\t")[0] for x in ref1_org]

# %%
# Get the Content of the Reference Sentences
ref0_con = [clean_text(x) for x in ref0_processed]
ref1_con = [clean_text(x) for x in ref1_processed]

# %%
ref0_org[:4], ref0_con[:4]
# Out:
# (["ever since joes has changed hands it 's just gotten worse and worse .",
#   'there is definitely not enough room in that part of the venue .',
#   'so basically tasted watered down .',
#   "she said she 'd be back and disappeared for a few minutes ."],
#  ["everes changed hands just gotten worse and worse.\tEver since joes has changed hands it's gotten better and better.",
#   'there is not room in of the.There is so much room in that part of the venue',
#   "so basically watered.\tIt didn't taste down at all.",
#   "she'be back a few minutes.\tShe said she'd be back, and didn't disappear at all."])

# %%
def get_train_content(text):
    return text.split("<START>")[0].split("<CON_START>")[1].strip()

# %%
def get_train_attrs(text):
    return text.split("<CON_START>")[0].replace("<ATTR_WORDS>","").strip().split()

# %%
get_train_attrs(train0_processed[0])
# Out:
# ['mistaken', '.']

# %%
train0_processed[:4], train1_processed[:4]
# Out:
# (['<ATTR_WORDS> mistaken . <CON_START> i was sadly mistaken. <START> i was sadly mistaken . <END>',
#   '<ATTR_WORDS> to hoagies , is mill . <CON_START> so on theagies, the italian general run of the <START> so on to the hoagies , the italian is general run of the mill . <END>',
#   '<ATTR_WORDS> meat a lettuce . <CON_START> minimal and ton of shredded lettuce. <START> minimal meat and a ton of shredded lettuce . <END>',
#   '<ATTR_WORDS> special not tag . <CON_START> nothing really & worthy of the $ _num_ price tag. <START> nothing really special & not worthy of the $ _num_ price tag . <END>'],
#  ['<ATTR_WORDS> food . <CON_START> excellent food. <START> excellent food . <END>',
#   '<ATTR_WORDS> service . <CON_START> superb customer service. <START> superb customer service . <END>',
#   '<ATTR_WORDS> have specials good . <CON_START> they also daily and ice cream which is really good. <START> they also have daily specials and ice cream which is really good . <END>',
#   "<ATTR_WORDS> it 's a good hoagie . <CON_START> it'a toasted hoagie. <START> it 's a good toasted hoagie . <END>"])

# %%
# get content
train0_con = [get_train_content(x) for x in train0_processed]
train1_con = [get_train_content(x) for x in train1_processed]

# %%
train0_con[:4], train1_con[:4]
# Out:
# (['i was sadly mistaken.',
#   'so on theagies, the italian general run of the',
#   'minimal and ton of shredded lettuce.',
#   'nothing really & worthy of the $ _num_ price tag.'],
#  ['excellent food.',
#   'superb customer service.',
#   'they also daily and ice cream which is really good.',
#   "it'a toasted hoagie."])

# %%
# Fatch attributes from the training data
attrs_neg = [get_train_attrs(x) for x in train0_processed]
attrs_pos = [get_train_attrs(x) for x in train1_processed]

# %%
# Get TFIDF vectors for Training and Reference
tfidf = TfidfVectorizer()
conts_vecs = tfidf.fit_transform(train0_con + train1_con)
conts_pos_vecs = conts_vecs[:len(train1_con)]
conts_neg_vecs = conts_vecs[len(train1_con):len(train1_con)+len(train0_con)]
conts_from_pos_ref_vecs = tfidf.transform(ref1_con)
conts_from_neg_ref_vecs = tfidf.transform(ref0_con)

# %% [markdown]
# #### AnnoyIndex is used to store the TFIDF vectors of training set and retrieve nearest neighbours of the reference content

# %%
# !pip install annoy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting annoy
#   Downloading annoy-1.17.2.tar.gz (647 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 647.4/647.4 kB 19.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: annoy
#   Building wheel for annoy (setup.py) ... done
#   Created wheel for annoy: filename=annoy-1.17.2-cp39-cp39-linux_x86_64.whl size=582240 sha256=85b9534e2d633ac7d30f040c8604898dff63b1063f4e7e300368db29f3c8a2a5
#   Stored in directory: /root/.cache/pip/wheels/f2/2e/e4/f3ae385c375b87982a2a70055061d4a6330ef4f60817e717e3
# Successfully built annoy
# Installing collected packages: annoy
# Successfully installed annoy-1.17.2

# %%
from annoy import AnnoyIndex

# %%
train0_tree = AnnoyIndex(conts_neg_vecs.shape[-1])
train1_tree = AnnoyIndex(conts_pos_vecs.shape[-1])
# Out:
# <ipython-input-22-ae04ec596fa9>:1: FutureWarning: The default argument for metric will be removed in future version of Annoy. Please pass metric='angular' explicitly.
#   train0_tree = AnnoyIndex(conts_neg_vecs.shape[-1])
# <ipython-input-22-ae04ec596fa9>:2: FutureWarning: The default argument for metric will be removed in future version of Annoy. Please pass metric='angular' explicitly.
#   train1_tree = AnnoyIndex(conts_pos_vecs.shape[-1])

# %%
# We have randomly selected training samples to control the memory usage
neg_idxs = np.random.choice(conts_neg_vecs.shape[0], size=50000)
pos_idxs = np.random.choice(conts_pos_vecs.shape[0], size=50000)

# %%
#for i in trange(conts_neg_vecs.shape[0]):
for i in trange(len(neg_idxs)):
    np_array = conts_neg_vecs[neg_idxs[i]].toarray()[0]
    train0_tree.add_item(i,np_array)
# Out:
# 100%|██████████| 50000/50000 [02:12<00:00, 377.73it/s]

# %%
train0_tree.build(50)
train0_tree.save('tfidf_train0.ann')
# Out:
# True

# %%
ref1_con[0:3], " ".join(attrs_neg[neg_idxs[0]])
# Out:
# (["it'small they make right at.it's small yet they make you feel like a stranger.",
#   "i will going and enjoying place!i't be going back and suffering at this terrible place!",
#   'the drinks affordable a good pour.\tthe were expensive and half.'],
#  'crap .')

# %%
with open("/content/drive/MyDrive/riya/data/yelp/processed_files_with_bert_with_best_head/delete_retrieve_edit_model/tfidf/reference_1.txt", "w") as out_fp:
    for i in range(conts_from_pos_ref_vecs.shape[0]):
        x = conts_from_pos_ref_vecs[i].toarray()[0]
        inx,dis = train0_tree.get_nns_by_vector(x, 1, include_distances=True)
        ref_sen = ref1_con[i]
        #ref_sen = processed_ref0[i].replace("<POS>","").replace("<NEG>","").replace("<CON_START>","").replace("<START>","")
        #print(dis,"\t",ref0_org[i], "\t" ,train1_data[inx[0]], train1_attr[inx[0]])
        out_str = "<ATTR_WORDS> " + " ".join(attrs_neg[neg_idxs[inx[0]]]) + " <CON_START> " + ref_sen.strip() + " <START>" + "\n"
        print(out_str)
        out_fp.write(out_str)
# Out:
# <ATTR_WORDS> exciting . <CON_START> it'small they make right at.it's small yet they make you feel like a stranger. <START>
#
# <ATTR_WORDS> and unhappy . <CON_START> i will going and enjoying place!i't be going back and suffering at this terrible place! <START>
#
# <ATTR_WORDS> does dq exist ? <CON_START> the drinks affordable a good pour.	the were expensive and half. <START>
#
# <ATTR_WORDS> there a . <CON_START> my husband aen sandwich loved it	my husband got reuben sandwich, he hated it. <START>
#
# <ATTR_WORDS> could n't tell difference . <CON_START> i signed for email and got coupon.I up for email and got spam. <START>
#
# <ATTR_WORDS> wo n't staying again . <CON_START> i'definitely giving them a try.	'd recommend not a try. <START>
#
# <ATTR_WORDS> course . <CON_START> i highly e m painting.	I highly avoiding e & m. <START>
#
# <ATTR_WORDS> horrible . <CON_START> otherwise great and we will again.other a terrible and we will not go again. <START>
#
# <ATTR_WORDS> tax and delivery , _num_ . <CON_START> good drinks and company.	watery drinks, and bad company. <START>
#
# <ATTR_WORDS> honestly , the store _num_ . <CON_START> oh i my geek back on!	 I't get band geek back on anymore! <START>
#
# <ATTR_WORDS> disgusting . <CON_START> i was and made me feel so comfortable and.she did me feel welcomed <START>
#
# <ATTR_WORDS> last sunday , . <CON_START> great food steak tuna were both great.	the steak tuna were to par <START>
#
# <ATTR_WORDS> potato and cold . <CON_START> everything is and delicious!	everything was so stale <START>
#
# <ATTR_WORDS> below average carolina barbeque . <CON_START> the biscuits gravy good.	the biscuits were hard and gravy was bland <START>
#
# <ATTR_WORDS> is about _num_ _num_ bed . <CON_START> i actually wait come back next year!	i would not return here <START>
#
# <ATTR_WORDS> wo n't be back . <CON_START> they were helpful kind, priced.They've been more helpful, kind, and reasonably priced. <START>
#
# <ATTR_WORDS> one only alcohol . <CON_START> god i pei wei.	god I don like peii. <START>
#
# <ATTR_WORDS> was _num_ star , that . <CON_START> friendly delicious bagels cheese.	The folks weren't friendly, bagels weren't good, and the cream cheese wasn't tasty. <START>
#
# <ATTR_WORDS> in hurry hours . <CON_START> you'see once you.	'll why I don't like it once you get there. <START>
#
# <ATTR_WORDS> back . <CON_START> everyone that spoke was very helpful kind.Everyone I spoke wasn't helpful or kind. <START>
#
# <ATTR_WORDS> ca n't place , all . <CON_START> the variety sushi makes for a good eating.There limited variety rolls. <START>
#
# <ATTR_WORDS> sucks . <CON_START> and every has a positive one.	Every experience has been awful. <START>
#
# <ATTR_WORDS> dry well price . <CON_START> ste professional found exactly to fit in our space.	Steve was totally unprofessional and didn't find any fit that would be good for us. <START>
#
# <ATTR_WORDS> at hut _num_ , _num_ . <CON_START> this golf is of the best in my opinion	 Golf Club major disappointment. <START>
#
# <ATTR_WORDS> did n't even marsala ! <CON_START> excellent dentist staff!	Minimally qualified dentist and staff. <START>
#
# <ATTR_WORDS> as have grease . <CON_START> portions very and food isastically flavorful	ions are small and food is not flavorful. <START>
#
# <ATTR_WORDS> _num_ ) amenities . <CON_START> always fresh fat and delicious.	always bland fat, and bad. <START>
#
# <ATTR_WORDS> was ... joke ! <CON_START> these two are.	these two women are not professionals. <START>
#
# <ATTR_WORDS> mention they n't silverware ? <CON_START> the most thing of course, the food	the most important be the food. <START>
#
# <ATTR_WORDS> bland ! <CON_START> we were so.	we were both unimpressed. <START>
#
# <ATTR_WORDS> 'm disappointed and back . <CON_START> very good, impressed with selection and quality.the was bad little selection <START>
#
# <ATTR_WORDS> to cabo show . <CON_START> the menu very, healthy, and tasty.the was weak food bland <START>
#
# <ATTR_WORDS> them a before . <CON_START> she was on they were delicious.	she not correct and it <START>
#
# <ATTR_WORDS> n't your money , . <CON_START> i love place the service is always great!hate place, bad <START>
#
# <ATTR_WORDS> mistake . <CON_START> perfect spot shop gift!	bad shop for a gift though <START>
#
# <ATTR_WORDS> called tell nothing . <CON_START> a great if want nice a steal	a great stop you want bad things at scammy prices <START>
#
# <ATTR_WORDS> n't i did n't you ! <CON_START> the atmosphere fun the staff treats well.the was lame the staff treats you like dirt <START>
#
# <ATTR_WORDS> were , did n't flavor . <CON_START> their front is much cheaper thanmart!their line is much more expensive than petsmart! <START>
#
# <ATTR_WORDS> would n't even could . <CON_START> this is place still the and treated right.	this is a place where the customer comes last and is mistreated <START>
#
# <ATTR_WORDS> to here they 've business . <CON_START> i their location rightottsdale road.	I hate how their location is inconveient to get to from scottsdale road <START>
#
# <ATTR_WORDS> her with well . <CON_START> their the i have well as their ranch!	their pizza is the worst i have ever had as well as their ranch! <START>
#
# <ATTR_WORDS> out soggy disgusting . <CON_START> i so and will for future services.	i'm so sad and will definitely not go back for future services. <START>
#
# <ATTR_WORDS> was another _num_ order . <CON_START> seems high to everyai place	ems pretty low compared to every other thai place. <START>
#
# <ATTR_WORDS> , card , shipping . <CON_START> she did most job.	she did the most awful job. <START>
#
# <ATTR_WORDS> is busy though , do n't wait . <CON_START> really enjoyed beautiful.	really didn't enjoy the ugly range. <START>
#
# <ATTR_WORDS> man , school . <CON_START> they have fantastic and a staff.the was not that great and they had no idea what they were doing <START>
#
# <ATTR_WORDS> assume any ridiculous . <CON_START> definitely place keep in mind.	not a place i would recommend <START>
#
# <ATTR_WORDS> have make stock . <CON_START> great place hang, grab a brews!	too noisy and the food and brews are not that great <START>
#
# <ATTR_WORDS> wrong . <CON_START> the lunch dinner are very good as well.l and dinner very good <START>
#
# <ATTR_WORDS> i 'm recommending my here . <CON_START> charl was neat and professional.	a on dirty sideprofessional <START>
#
# <ATTR_WORDS> meal will chance . <CON_START> theones awesome and they have is perfect.	the calzones are awful and the lunch special they have is pathetic. <START>
#
# <ATTR_WORDS> zero moving pass . <CON_START> i will return!	i will definitely not return often! <START>
#
# <ATTR_WORDS> place ! <CON_START> they have sou everyday.	they have gross soups everyday. <START>
#
# <ATTR_WORDS> special . <CON_START> nice people prompt and clearly expert.	negative, service and expert. <START>
#
# <ATTR_WORDS> back . <CON_START> produ very priced and organic produce.	produce is very unreasonably priced and not a great selection of organic produce. <START>
#
# <ATTR_WORDS> the bull heard . <CON_START> the food is.	the food here is gross <START>
#
# <ATTR_WORDS> gross ! <CON_START> first time came, i just wanted new	first time i came in i knew i just wanted to leave <START>
#
# <ATTR_WORDS> restaurant . <CON_START> certainly good if going arts event.	certainly a bad choice when going to a performing arts center event <START>
#
# <ATTR_WORDS> he 's rude ! <CON_START> this place been great sushi andashimi years	this has been making horrible sushi for years <START>
#
# <ATTR_WORDS> just talking window . <CON_START> even in, have decent patronage.	even summer they are no <START>
#
# <ATTR_WORDS> cart slow . <CON_START> you helped all of, and travel knowledge!	no one helped me while i was waiting and no one knew much about traels <START>
#
# <ATTR_WORDS> , average . <CON_START> i with best buds excellent wine and food.	the food and wine was terrible and my best buds said the same thing <START>
#
# <ATTR_WORDS> busy . <CON_START> we went a of eight had a time	the place was too packed, we did not enjoy it <START>
#
# <ATTR_WORDS> curt , if rude , employees . <CON_START> the service always wonderful.	the service was frustrating <START>
#
# <ATTR_WORDS> cared the problems . <CON_START> thanks for our night an event to remember.our special night was <START>
#
# <ATTR_WORDS> is slow , and . <CON_START> i had sp ome huge and.the spanish omelet was small and bland tasting <START>
#
# <ATTR_WORDS> pressure borderline low . <CON_START> they have big chairs and eachure station fairly.	the were small and disappointing <START>
#
# <ATTR_WORDS> 'm not sure start . <CON_START> the wait is attractive and friendly!	the staff was not friendly <START>
#
# <ATTR_WORDS> strong . <CON_START> also, food great!	the food was just ok <START>
#
# <ATTR_WORDS> dirty old ! <CON_START> the color she on mys hair great	the color used on my friend was a bad choice <START>
#
# <ATTR_WORDS> we felt leaving . <CON_START> it is and staff is always friendly.	it is bad and is always <START>
#
# <ATTR_WORDS> helpful . <CON_START> friendly and with fun atmosphere and food.un and unwcoming with a bad atmosphere and food <START>
#
# <ATTR_WORDS> , are here . <CON_START> the chickeni had was absolutely fantastic!	the chickeni was! <START>
#
# <ATTR_WORDS> the experience company . <CON_START> it is fun sit at the.	it is not fun to sit at the bat <START>
#
# <ATTR_WORDS> had pasta in sauce . <CON_START> the soup absolutely die for.	the soup make you want to <START>
#
# <ATTR_WORDS> not to experience . <CON_START> the bestx food inoenix area	the worst meican food in the phoenix area. <START>
#
# <ATTR_WORDS> horrible ! <CON_START> they are, and attentive needs.they unprofessional, hurried and neglectful of our needs. <START>
#
# <ATTR_WORDS> to leave wo n't back . <CON_START> their lunch is great value!	their lunch is a poor value. <START>
#
# <ATTR_WORDS> chance ? <CON_START> our experience this was positive.	our experience this business was negative. <START>
#
# <ATTR_WORDS> like teeth office . <CON_START> the awesome location is heart of old town!	the staff is sub-par and location is inconveniently far from old town. <START>
#
# <ATTR_WORDS> n't happy location . <CON_START> you have sit to get the experience from place	S outside makes this place worse. <START>
#
# <ATTR_WORDS> are , dirty . <CON_START> the food delicious plentiful.	The food was tough and dry. <START>
#
# <ATTR_WORDS> _num_ marked report . <CON_START> and theettine al absolutelyumptious!	The fettuccine alfredo was a disappointment. <START>
#
# <ATTR_WORDS> asked my it . <CON_START> we dropped rental of at two weeks.We avoided dropping the rental truck here two weeks ago. <START>
#
# <ATTR_WORDS> were actually pretzels . <CON_START> this adds last touch to already an place	This adds the final straw to a disappointing place. <START>
#
# <ATTR_WORDS> me . <CON_START> prices a high but worth.	ices a tad and not worth it. <START>
#
# <ATTR_WORDS> could this would . <CON_START> the message is also.	the message therapist is terrible also. <START>
#
# <ATTR_WORDS> were super ours . <CON_START> came with family.	came here without my family. <START>
#
# <ATTR_WORDS> big apple , you list . <CON_START> the owner, will go with you	the owner replied i will not go in half with you. <START>
#
# <ATTR_WORDS> place . <CON_START> the escot delicious, and perfectly. theargot gross, and seasoned terribly. <START>
#
# <ATTR_WORDS> $ _num_ disappointing . <CON_START> britt gave a very transformed completely.	brittany gave me a very old haircut and ruined me completely. <START>
#
# <ATTR_WORDS> difficult busy . <CON_START> this been scot and it truly knows service.	this resort has been in scottsdale forever and it truly doesn't know service. <START>
#
# <ATTR_WORDS> cobblestone never calls . <CON_START> also the wont rule along plum.	also the crab wontons are awful along with the spicy plum sauce. <START>
#
# <ATTR_WORDS> bland . <CON_START> i have so dresses at of a!i have gotten so many dresses at a terrible price! <START>
#
# <ATTR_WORDS> not why nothing ? <CON_START> all around place grab a drink two.all bad place grab a drink or two. <START>
#
# <ATTR_WORDS> adequate ? <CON_START> the chocolate was one desserts i've ever had.	the chocolate cake was horrible, worst i had eaten in a while <START>
#
# <ATTR_WORDS> back '' . <CON_START> beautiful and staff.	the scenery and was poor along with <START>
#
# <ATTR_WORDS> worst . <CON_START> nice wine atx retail rather the more 3.	the list was poor and overpriced <START>
#
# <ATTR_WORDS> decide buy online , luck ! <CON_START> we loved day the river't to go back!	our day on the river was horrible don't want to return <START>
#
# <ATTR_WORDS> avoid ! <CON_START> if youre and are this is place you.	no matter your age, you won't like it <START>
#
# <ATTR_WORDS> twenty on dinner . <CON_START> i love star collection.	i can't their star design collection. <START>
#
# <ATTR_WORDS> told an _num_ rolls . <CON_START> i love fresh as well.	i don like their fresh juices. <START>
#
# <ATTR_WORDS> horrible . <CON_START> definitely must if you theoenix area.	definitely avoid if you are in the phoenix area. <START>
#
# <ATTR_WORDS> disappointed . <CON_START> oj anderemy did a great job!	 anderemy terrible job <START>
#
# <ATTR_WORDS> visited findlay around after work . <CON_START> tires alignment brakes and more.	no, alignment,, nothing. <START>
#
# <ATTR_WORDS> phone or elsewhere . <CON_START> it was good!	it was very bad too <START>
#
# <ATTR_WORDS> : terminal _num_ signs . <CON_START> staff : cute friendly.	staff: very ugly and mean <START>
#
# <ATTR_WORDS> not this all ! <CON_START> love the - at the phician.hate atern tea at the phoenician <START>
#
# <ATTR_WORDS> tea or street . <CON_START> their enil sauce perfectly comple this dish	their ench sauce ruined this dish <START>
#
# <ATTR_WORDS> so , there am open . <CON_START> beautiful and service.	horrible decoration and service <START>
#
# <ATTR_WORDS> food . <CON_START> very pleased service quality of work.	disased service and work <START>
#
# <ATTR_WORDS> pedicure i 've gotten . <CON_START> one of favorite to go for great steak	 of my favorite places to go for a steak <START>
#
# <ATTR_WORDS> my _num_ front . <CON_START> this place superummy!	this place is super yucky! <START>
#
# <ATTR_WORDS> here ! <CON_START> they are with decor.	they are cramped with gaudy decor <START>
#
# <ATTR_WORDS> tart , spices . <CON_START> this is go neighborhood place.	this is last I'd the neighborhood <START>
#
# <ATTR_WORDS> not giving chance . <CON_START> the people son were very good me.the at son weren't that good to me. <START>
#
# <ATTR_WORDS> i no order . <CON_START> the patio a place to 7pm	the patio isn a fun place to sit at at 7 pm. <START>
#
# <ATTR_WORDS> us . <CON_START> it was worth.	it wasn't worth it. <START>
#
# <ATTR_WORDS> lousy . <CON_START> oh sushie how i love!	 sushie, i loathe thee! <START>
#
# <ATTR_WORDS> , bad be ? <CON_START> she kept drinks and gave food recommendations	she didn't our drinks full and gave us poor food recommendations. <START>
#
# <ATTR_WORDS> do n't know business . <CON_START> l burgers i hadapeo ranch burger it was really tasty.	I  had the jalapeno ranch burger, it wasn't that tasty. <START>
#
# <ATTR_WORDS> problem rice , , vinegary . <CON_START> great keab and good service	Theb dishes and wasn't that good. <START>
#
# <ATTR_WORDS> tell was excuse . <CON_START> i got bag breakfast sandwich delicious	I got a bagel breakfast sandwich, it wasn't that good. <START>
#
# <ATTR_WORDS> downstairs in _num_ minutes . <CON_START> the service amazing the staff.The service wasn't that good, and the staff wasn't friendly at all. <START>
#
# <ATTR_WORDS> situation . <CON_START> pool tables inexpensive make this night out	ensive drinks and pool tables made this night not as fun. <START>
#
# <ATTR_WORDS> should be all ! <CON_START> the eggs always, the fruit always.eggs are not always fluffy, the fruit just ok <START>
#
# <ATTR_WORDS> skimp the veg . <CON_START> pricing both and reasonable.	the pricing is a bit much <START>
#
# <ATTR_WORDS> waiter our change , ? <CON_START> these guys top, honest and very reasonable.the are just might be honest <START>
#
# <ATTR_WORDS> side sour good , cool . <CON_START> they made feel i was at and their extended!	i like an outsider there <START>
#
# <ATTR_WORDS> dishonest . <CON_START> sometimes its simple cut, times is complicated.	the were bland and often the same <START>
#
# <ATTR_WORDS> order cheese it . <CON_START> giving an star customer service.	they should have zero starts <START>
#
# <ATTR_WORDS> could n't believe ears . <CON_START> it'a bowl of sweet happiness.	 a big bowl of <START>
#
# <ATTR_WORDS> choice . <CON_START> one of favoriteinese place to eat!	i would not visit this <START>
#
# <ATTR_WORDS> reps call rude . <CON_START> always good the too.	not that great after the river <START>
#
# <ATTR_WORDS> so , this was in . <CON_START> food good a went a long way.	the plate not good us <START>
#
# <ATTR_WORDS> , $ _num_ ticket . <CON_START> the service great would gladly go back.	i did like the i wont <START>
#
# <ATTR_WORDS> tax . <CON_START> i love pork.	the pork tacos were stale <START>
#
# <ATTR_WORDS> sorry , interested . <CON_START> everyone is and.	no one was friendly nor helpful <START>
#
# <ATTR_WORDS> of poor , overpriced . <CON_START> nothing but thoughts anyone i have sent their way	i would not their way <START>
#
# <ATTR_WORDS> visited about experience . <CON_START> enjoy they a lot.	they was not that <START>
#
# <ATTR_WORDS> they do n't service . <CON_START> jenn is and she really skin care.jenn sucks and makes skin care too expensive <START>
#
# <ATTR_WORDS> both , the that terrible . <CON_START> this is rare and i have it.	this is no rare gem and I am not happy to have found it <START>
#
# <ATTR_WORDS> pizza . <CON_START> this is darn pizza!	this is a pretty darn bad pizza <START>
#
# <ATTR_WORDS> and do n't card . <CON_START> everything weve ordered here has great tasting	 we've ordered her has been horrible tasting <START>
#
# <ATTR_WORDS> and would professional hairdresser and she sucked ! <CON_START> it is most thai in valley.it the least thai in the valley <START>
#
# <ATTR_WORDS> is worst . <CON_START> great staff wonderful.	The staff and food wasn't good. <START>
#
# <ATTR_WORDS> us . <CON_START> love the sauce chips are thick.I't like the mole sauce or the thin chips. <START>
#
# <ATTR_WORDS> forever for uncooked did n't even . <CON_START> go here you love it.	Don't here you won it. <START>
#
# <ATTR_WORDS> care good horrible . <CON_START> i loved ribs than the chicken	I't the ribs than the chicken. <START>
#
# <ATTR_WORDS> have n't eaten awhile . <CON_START> staff and ride terrific.	The staff and rides were terrible. <START>
#
# <ATTR_WORDS> not taking office . <CON_START> also were surprised last our dogs for shots.	we were unpleasantly surprised when we brought our dog for shots <START>
#
# <ATTR_WORDS> really have it . <CON_START> i reom the drunken for spicy lovers! )	I recommend against the drunken dragon noodles if you like spice <START>
#
# <ATTR_WORDS> ok prices doubled . <CON_START> for a chain place is great!	for local chain this place! <START>
#
# <ATTR_WORDS> _num_ . <CON_START> this place me home!	this place reminds why I want to <START>
#
# <ATTR_WORDS> sad my vet 's me . <CON_START> one of regular in scotdale.not of my spots in scottsdale <START>
#
# <ATTR_WORDS> could this would . <CON_START> i will go again!	I will never go here again! <START>
#
# <ATTR_WORDS> i 've had better return . <CON_START> st for, nice good service.	I stopped in for lunch, the wine list wasn't good neither was the service. <START>
#
# <ATTR_WORDS> smelled in . <CON_START> i this the place - family circus.	I don't like that the family circus is the place in the comics. <START>
#
# <ATTR_WORDS> recommend . <CON_START> it is international.	This isn't an international delight. <START>
#
# <ATTR_WORDS> , rick , mistake . <CON_START> it was so and quaint!	It wasn that cute or quaint. <START>
#
# <ATTR_WORDS> wifi awful . <CON_START> i love outside and the is affordable.	The outside seating is too packed, and happy hour never happens. <START>
#
# <ATTR_WORDS> nowhere . <CON_START> the atmosphere at sugar bowl is fun.	 atmosphere the sugar negative. <START>
#
# <ATTR_WORDS> rude . <CON_START> with that said i enjoyed the food.	 food just awful. <START>
#
# <ATTR_WORDS> is go . <CON_START> great food great!	Old decor, very bad food here. <START>
#
# <ATTR_WORDS> made rude blizzard . <CON_START> the food always.	The food is always old <START>
#
# <ATTR_WORDS> went and know . <CON_START> you in spend any and enjoy something amazing.	Dont go here, you will spend so much and have a bad experience. <START>
#
# <ATTR_WORDS> ok . <CON_START> all of food i had was.	 of food was and tasted old. <START>
#
# <ATTR_WORDS> too disturbing . <CON_START> so far great service.	So far the service was just rude. <START>
#
# <ATTR_WORDS> comfort was ok , carpet . <CON_START> rick is seriously guy!	Rick was the meanest person. <START>
#
# <ATTR_WORDS> crap port ! <CON_START> we ate yesterday happy hour was fantastic	 ate here a couple days ago and the happy hour was terrible. <START>
#
# <ATTR_WORDS> this , wo n't again . <CON_START> that'a find in a business.	that's so special business. <START>
#
# <ATTR_WORDS> include took . <CON_START> it'good food.	it's not very substantial food. <START>
#
# <ATTR_WORDS> they charge _num_ ! <CON_START> nice layout course was above average shape.	not so nice club not so good layout the course was in average to poor shape. <START>
#
# <ATTR_WORDS> unacceptable ! <CON_START> we'certainly back!	we probal won't be back. <START>
#
# <ATTR_WORDS> came , and came . <CON_START> the meataf when they is.	the meatloaf (if they even have it) is nothing special. <START>
#
# <ATTR_WORDS> n't fresh soggy . <CON_START> food here also good!	food here is also terrible! <START>
#
# <ATTR_WORDS> recommend . <CON_START> thank youanda i will be!	 thanksanda, won't be back! <START>
#
# <ATTR_WORDS> spending almost _num_ pleased . <CON_START> i love flavored.	i hate their flavored coffee. <START>
#
# <ATTR_WORDS> $ _num_ work . <CON_START> the staff us very welcome and comfortable.	the staff us feel and uncomfortable. <START>
#
# <ATTR_WORDS> when are food . <CON_START> the good from what is rather authentic.	the food is bad and from what i can tell is rather inauthentic. <START>
#
# <ATTR_WORDS> an chicken vegetable . <CON_START> i dent of oldtsdale to everyone.	I wouldn't recommend dentistry of old town scottsdale to anyone. <START>
#
# <ATTR_WORDS> down . <CON_START> my father decided upgrade my thismas.	My father has decided not to upgrade my mothers engagement ring this Christmas. <START>
#
# <ATTR_WORDS> how stay charge . <CON_START> the best in store are on racks.The deals in store are on these racks. <START>
#
# <ATTR_WORDS> our thinking mins . <CON_START> the guys areoo incredibly nice helpful.The here aren nice or helpful. <START>
#
# <ATTR_WORDS> eggs were real , crap . <CON_START> will bring my back for sure!	They won bring back vehicles. <START>
#
# <ATTR_WORDS> told area manager , sense . <CON_START> the fantastic next time for a hotter one.	the salsa was horrible although next time i will ask for a hotter one. <START>
#
# <ATTR_WORDS> a appointment could n't it ? <CON_START> great place have fresh anduts.not great place to have some fresh and delicious donuts. <START>
#
# <ATTR_WORDS> i 'm not _num_ about . <CON_START> came to breakfast and best yet.	came here to get breakfast and that was the worst decision yet. <START>
#
# <ATTR_WORDS> reliable , sale . <CON_START> they have excellent of combos to from.they a horrible of combos to choose from. <START>
#
# <ATTR_WORDS> _num_ star friendly . <CON_START> they were, too gre fluffy and.they were awful, too greasy and not fluffy or light. <START>
#
# <ATTR_WORDS> really , if want alternative ? <CON_START> great selection salads pasta itemsi	There isn't a great selection of salads or pasta in the deli. <START>
#
# <ATTR_WORDS> to table . <CON_START> overall good food and	Overall quality the food, and the service wasn't that good. <START>
#
# <ATTR_WORDS> said no me . <CON_START> everyone was nice professional.	Everyone was not nice or professional. <START>
#
# <ATTR_WORDS> , the i 've had . <CON_START> i got tam sampler.	Sadly, ordered the tamale. <START>
#
# <ATTR_WORDS> not back factory ! <CON_START> also matt super and helpful.	Also Matt't cool, that helpful. <START>
#
# <ATTR_WORDS> this take disappointed . <CON_START> cleaned plate perfect amount of food.	the food was not enough <START>
#
# <ATTR_WORDS> practices ! <CON_START> and again the is incredibly delicious!	i had better food for <START>
#
# <ATTR_WORDS> there ! <CON_START> but it definitely the wait.	definitely not worth the wait <START>
#
# <ATTR_WORDS> , all there . <CON_START> grims the most place in arizona.	claiming to be the best pizza in arizona, i dont think that is correct at all <START>
#
# <ATTR_WORDS> check us delivered . <CON_START> nothing but customer every time i here.the service here a lot to be desired. <START>
#
# <ATTR_WORDS> could n't it . <CON_START> great service the.	Poor service, and awful staff. <START>
#
# <ATTR_WORDS> many in visit . <CON_START> i also dessert when i have sweet tooth	ont recommend dessert here, very old tasting. <START>
#
# <ATTR_WORDS> does n't it . <CON_START> i always a dish here to eat.	 have worst selection here <START>
#
# <ATTR_WORDS> caesar w steak . <CON_START> this is far favorite pizza.	This is far worst pizzae had. <START>
#
# <ATTR_WORDS> to salmon . <CON_START> the super and quick especially with the crowd.	The bartender was so rude, and very slow to help us out. <START>
#
# <ATTR_WORDS> frankly , i do n't business . <CON_START> service was as continued to check our table	 was terrible they continued to ignore our table. <START>
#
# <ATTR_WORDS> one my hotel . <CON_START> thank you for awesome!	no thank you ladies for being awful! <START>
#
# <ATTR_WORDS> frustrated . <CON_START> awesome fast, these their.	awful and slow service, these guys really don't know their stuff. <START>
#
# <ATTR_WORDS> almost _num_ eat . <CON_START> a great to.	a terrible museum to visit. <START>
#
# <ATTR_WORDS> customer . <CON_START> nice for to and work a great!nice for me to go and work and have a bad breakfast! <START>
#
# <ATTR_WORDS> then sent . <CON_START> okay and tastings at once a.Awful, and not good tasting. <START>
#
# <ATTR_WORDS> service . <CON_START> our waitress the, very accommodating.	Our was worst,. <START>
#
# <ATTR_WORDS> _num_ ... sandwiches , potatoes . <CON_START> while the is, what is first-rate.	The menu is complicated, very low quality items. <START>
#
# <ATTR_WORDS> slaw awful . <CON_START> its not but get good value here.	 expensive and bad. <START>
#
# <ATTR_WORDS> ever ! <CON_START> nice menu good, great for both and!	Terrible menu, high prices, bad customer service. <START>
#
# <ATTR_WORDS> atmosphere what clean . <CON_START> good food great on wingsuesdays	eful food, high prices and the tuesday wings are too small <START>
#
# <ATTR_WORDS> condiment request , , ? <CON_START> the place busy the service was!	y and had wait an hour to get my food <START>
#
# <ATTR_WORDS> sweet was skin . <CON_START> ton i to go was just as good.	i ordered to go but it seemed like they didnt cook me fresh food <START>
#
# <ATTR_WORDS> knew is hospital . <CON_START> this place some food.	this place does not have the best food <START>
#
# <ATTR_WORDS> wall absurd ! <CON_START> the two men front are always kind.the men inf were rude and did not help me <START>
#
# <ATTR_WORDS> showed care product . <CON_START> the great the fish the drinks just excellent.	the salsa is thin, the fish smelled, the drinks just watery. <START>
#
# <ATTR_WORDS> i 'm done ! <CON_START> i place much i about purchasing a franchise.	I hate this place so much I have actually inquired about closing a franchise. <START>
#
# <ATTR_WORDS> sushi _num_ , school . <CON_START> and the eniladas were great!	and the ench were horrible <START>
#
# <ATTR_WORDS> nothing . <CON_START> the definitely made and eat it all day.	the bread is definitely not home made and I couldn't eat it all day. <START>
#
# <ATTR_WORDS> first , horrendous . <CON_START> the huge the food, fresh and good.	the portions were small, the food came out cold, old, and bland. <START>
#
# <ATTR_WORDS> just cubes fish . <CON_START> a the side but makes up for it.	a bit on the noisy side and the spoiled food doesn't make up for it. <START>
#
# <ATTR_WORDS> bad . <CON_START> ambiance setting superb.	ambiance and were sub-par <START>
#
# <ATTR_WORDS> awful . <CON_START> pizza cooked perfection and fast!	p was to a took forever! <START>
#
# <ATTR_WORDS> that . <CON_START> ourik care of i very well.	our bartender erik didn't take care of my fiance and i very well. <START>
#
# <ATTR_WORDS> were cooked again , soggy . <CON_START> everyone who there always so friendly.everyone works there is always so angry and unfriendly. <START>
#
# <ATTR_WORDS>  <CON_START> i love corn appetizerI love corn appetizer it's the only good thing on the menu. <START>
#
# <ATTR_WORDS> the are '' . <CON_START> orderedv ranche was delicious!	Ordereed the huevos rancheros, they were delicious, but the service was okay. <START>
#
# <ATTR_WORDS> awhile to recommended . <CON_START> the customer in location is great!	This has customer service okay food. <START>
#
# <ATTR_WORDS> was full crazy . <CON_START> the fireacker and duck a.	The firecracker shrimp is duck is the only winner on the menu. <START>
#
# <ATTR_WORDS> curt , if rude , employees . <CON_START> service was to!	The service was wonderful but food was! <START>
#
# <ATTR_WORDS> ick . <CON_START> the service friendly attentive.	The service was awful and hurtful. <START>
#
# <ATTR_WORDS> waited _num_ seated . <CON_START> great food awesome!	Awful food, and poor customer service. <START>
#
# <ATTR_WORDS> _num_ . <CON_START> this place kicks.	This place is just terrible. <START>
#
# <ATTR_WORDS> , would star . <CON_START> bisc and are a great item too	 biscuits and are very bad items here. <START>
#
# <ATTR_WORDS> , sprint wrong . <CON_START> always a experience with the the rest the.	Always a poor experience the owner and staff are rude. <START>
#
# <ATTR_WORDS> _num_ ! <CON_START> well worth out gem.	it's not gem worth searching out <START>
#
# <ATTR_WORDS> word ! <CON_START> my husband i our 3 here.my and i didn't enjoy our 3rd anniversary hear. <START>
#
# <ATTR_WORDS> stay again either . <CON_START> this golf that is is in great condition.	this is a golf course that is tucked away it is in poor condition. <START>
#
# <ATTR_WORDS> disappointed . <CON_START> plus my wine were delish!	plus sparkling wine flights were <START>
#
# <ATTR_WORDS> , have selections . <CON_START> pricy the pies are delicious!	pr and cheese pies! <START>
#
# <ATTR_WORDS> though . <CON_START> the bq was good.	hated bq salmon aweful <START>
#
# <ATTR_WORDS> to anything one . <CON_START> the of thanksgiving was sweet cakes pecan pie.	the thanksgiving dinner was not what i expected especially the sweet cakes pecan pie <START>
#
# <ATTR_WORDS> drove _num_ renew . <CON_START> even theiramed are amazing.	steamed were not properly ste <START>
#
# <ATTR_WORDS> was served salad . <CON_START> this place a go ifre a to!	if you are a bride to be stay away <START>
#
# <ATTR_WORDS> basil 's will business . <CON_START> excellent of, very unique.	the are nothing to write <START>
#
# <ATTR_WORDS> and tasteless . <CON_START> mustard ribs a must.	mustard beef ribs was too hard <START>
#
# <ATTR_WORDS> ever ! <CON_START> i had burger and it was and very!the burger not juicy enough and had no flavor <START>
#
# <ATTR_WORDS> give stars . <CON_START> i rate experience followed.	the experience was horrible <START>
#
# <ATTR_WORDS> sirloin grilled potato . <CON_START> always order tatziki everything you!the tzatziki sauce was very bland to me <START>
#
# <ATTR_WORDS> disgusting . <CON_START> my meal very and flavorful.	the meal not properly and flavor <START>
#
# <ATTR_WORDS> number . <CON_START> try anything the and you will glad you in	i not try anything on their menu <START>
#
# <ATTR_WORDS> yet find charlotte . <CON_START> bartender a dirty martini!	bart gave a wateredini <START>
#
# <ATTR_WORDS> his wo n't again . <CON_START> omgls tavern is awesome!	cs tavern you improve your service <START>
#
# <ATTR_WORDS> service and establishment . <CON_START> other than,'s great!	other that, i wont <START>
#
# <ATTR_WORDS> part disappointing . <CON_START> best breakfast had my recent trip scotdale	the was cold, did not enjoy it <START>
#
# <ATTR_WORDS> , have information . <CON_START> extremely attentive genuinely good person.	they didn pay attention, horrible <START>
#
# <ATTR_WORDS> golfing ever week . <CON_START> it'basic traditional,ican food is and tastes great.	the food was bland and not that traditional <START>
#
# <ATTR_WORDS> ever ! <CON_START> food is fresh amazing!	food was old and stale <START>
#
# <ATTR_WORDS> have problem building . <CON_START> the environment cozy the servers and on of.	the place was not inviting and staff seemed aloof <START>
#
# <ATTR_WORDS> not . <CON_START> fish tacos pretty.	fish tacos were the worst I had <START>
#
# <ATTR_WORDS> for _num_ eating . <CON_START> absolutely hands the dentist office east valley	 hands down the worst dentist office in the east valley! <START>
#
# <ATTR_WORDS> flight delayed flight . <CON_START> they are very.	they are all very unfriendly. <START>
#
# <ATTR_WORDS> best wanted family . <CON_START> he always gorgeous is so pick up!	he always looks ugly and is so sad when i pick him up! <START>
#
# <ATTR_WORDS> is back . <CON_START> i lovealian i eat here.	i hatealian and't eat here often. <START>
#
# <ATTR_WORDS> mexican food setting . <CON_START> quality of is.	quality of food is awful. <START>
#
# <ATTR_WORDS> did n't figure long . <CON_START> the excellent my host nice and helpful.	my hostess was terrible and slow, and the service was not on par with nearby places <START>
#
# <ATTR_WORDS> the course phoenix . <CON_START> the best in.	the bar had very few selections <START>
#
# <ATTR_WORDS> over-priced & do n't a ! <CON_START> they are doing good job.	did not a good job at <START>
#
# <ATTR_WORDS> _num_ % wrong . <CON_START> russ a qualified tech.	the tech not know what to <START>
#
# <ATTR_WORDS> was served salad . <CON_START> when we into, this place come!	this is the last place i would go if i came into town <START>
#
# <ATTR_WORDS> recommend . <CON_START> thank youiesta lunch with you always good	unch was, i wont be back <START>
#
# <ATTR_WORDS> sat hours . <CON_START> they also the price in the area.	the prices were too high <START>
#
# <ATTR_WORDS> not with call . <CON_START> green ch chimis are fantastic.	the greenile chimis were <START>
#
# <ATTR_WORDS> inside it . <CON_START> thanks for perfect.	did not do a great job with the repair <START>
#
# <ATTR_WORDS> to me done . <CON_START> casual, food.	the food was upscale the ath was boring <START>
#
# <ATTR_WORDS> money something did n't or did n't . <CON_START> had dinner last and it was great.	had dinner last night sucked <START>
#
# <ATTR_WORDS> frills . <CON_START> the marinara is so flavorful.	theinara sauce had <START>
#
# <ATTR_WORDS> awful . <CON_START> they are nice accommodating.	they are not nice or accommodating <START>
#
# <ATTR_WORDS> again . <CON_START> the service top and the a bit heaven	the service was bad and the food was hellish <START>
#
# <ATTR_WORDS> it cant this . <CON_START> it can pricey but it is worth it	it can be isn't even worth it <START>
#
# <ATTR_WORDS> heard he said , serious ? <CON_START> wonder staff wonderful food, prices.hor staff, food, disgusting prices. <START>
#
# <ATTR_WORDS> awful . <CON_START> portions prices great!	portions n prices were unacceptable! <START>
#
# <ATTR_WORDS> corn tortillas were hard . <CON_START> every themselves there was from our entire group.	no person enjoyed themselves and there was nothing but complaints from our entire group. <START>
#
# <ATTR_WORDS> reservations still seated . <CON_START> outstandingian not to mention.	g persian not to mention service. <START>
#
# <ATTR_WORDS> are constantly busy , tables . <CON_START> thank you a evening!	thank you for a forgettable evening! <START>
#
# <ATTR_WORDS> dishes . <CON_START> my daughter great.	my daughter was treated terribly <START>
#
# <ATTR_WORDS> parking and rude . <CON_START> thorough reasonably and they phone when promptly	i called so many times no one answered at all <START>
#
# <ATTR_WORDS> got to gone . <CON_START> they were friendly apologetic.	no one was helpful nor friendly there <START>
#
# <ATTR_WORDS> avoid stores plague . <CON_START> the wine was best part.	not enough wine choices <START>
#
# <ATTR_WORDS> , is seen . <CON_START> it'a better option than club scene	i would rather the club than here <START>
#
# <ATTR_WORDS> her attitude . <CON_START> i ordered car asada steak it was perfectly	theada steak was barely cooked and raw <START>
#
# <ATTR_WORDS> back . <CON_START> that comes the location though.	this location is too small <START>
#
# <ATTR_WORDS> friendly ordinary . <CON_START> fun place go beer.	too crowded and a place to a beer <START>
#
# <ATTR_WORDS> was politely me . <CON_START> it is very oriented and we that too	 many single, not a place for your family <START>
#
# <ATTR_WORDS>  <CON_START> even the were.	the sides were to expensive and small <START>
#
# <ATTR_WORDS> they a alcohol . <CON_START> she did amazing on my color my cut	the job was my color and cut <START>
#
# <ATTR_WORDS> is furniture , it 's service . <CON_START> the owner aoot and the is very.the owner boring and the place not that welcoming <START>
#
# <ATTR_WORDS> piece pizza . <CON_START> totally come next time i'm in.	won't <START>
#
# <ATTR_WORDS> to anyone . <CON_START> he was professional courteous.	se unprofessional and al <START>
#
# <ATTR_WORDS> when busy . <CON_START> this course one the finest in the area.the course is not <START>
#
# <ATTR_WORDS> pho hard . <CON_START> ifre that sort by and check it out!	Even if you're into that sort of thing, I wouldn't check it out. <START>
#
# <ATTR_WORDS> all agreed , and did n't pizza . <CON_START> i enjoy here lunch to get slices.I coming here lunch to get the slices. <START>
#
# <ATTR_WORDS> me . <CON_START> it is half day trip area	It's a long, half a day trip from phoenix area. <START>
#
# <ATTR_WORDS> bugs this weekend . <CON_START> love the of place!	I hate the of this place. <START>
#
# <ATTR_WORDS> service horrible horrible . <CON_START> the staff all friendly and of there.The staff are not friendly and not on top of their jobs. <START>
#
# <ATTR_WORDS> bland . <CON_START> corn bread also!	the corn bread was stale <START>
#
# <ATTR_WORDS> salad . <CON_START> food super well.	the food was very over priced <START>
#
# <ATTR_WORDS> wings bone . <CON_START> they loved rock.	the rock climb was ok <START>
#
# <ATTR_WORDS> _num_ . <CON_START> super tasty a better deal chain sub.the food was bland and not as good as chain joints <START>
#
# <ATTR_WORDS> unacceptable . <CON_START> by far best i have in a shop	possibly the worst i've had at an auto shop <START>
#
# <ATTR_WORDS> awful place , do n't there . <CON_START> so happy my to go here.	so with my decision to <START>
#
# <ATTR_WORDS> ever . <CON_START> it was inexpensive they played good music videos.it pretty expensive bad music videos <START>
#
# <ATTR_WORDS> , an guess . <CON_START> very throw atmosphere vintage ice creamlor.veryback atmosphere old ice cream parlor <START>
#
# <ATTR_WORDS> it 's disgusting . <CON_START> sit at bar eat the small plates.	 at bar and small plates <START>
#
# <ATTR_WORDS> was tasteless , priced . <CON_START> the grounds always clean.	the grounds are always very filthy <START>
#
# <ATTR_WORDS> is someone with . <CON_START> i just from delightful stay camelback	 just returned from a terrible stay at the camelback. <START>
#
# <ATTR_WORDS> place . <CON_START> a steak shrimp an enada.a steak, tiny shrimp and a mediocre enchilada. <START>
#
# <ATTR_WORDS> not this know . <CON_START> they go and!	they won't put out any extra effort! <START>
#
# <ATTR_WORDS> slow . <CON_START> i'been several times has great.	i've been here several times and every time has been disappointing. <START>
#
# <ATTR_WORDS> and ca n't that 've . <CON_START> the good that vision had visit better.	the bad news that my vision had deteriorated made the visit even worse. <START>
#
# <ATTR_WORDS> , will here . <CON_START> it is a little place getanky.	It is cool to relax there, but it is pretty boring after awhile <START>
#
# <ATTR_WORDS> disappointed their sauce . <CON_START> we recommend &an auto we.	I recommend imports and american auto service to anyone that wants just okay service <START>
#
# <ATTR_WORDS> is service . <CON_START> the girls very and really push at all.	The girls are friendly and attractive, but a bit pushy <START>
#
# <ATTR_WORDS> wo n't be back . <CON_START> its quiet nice are here.	Nice people here but it quiet and boring <START>
#
# <ATTR_WORDS> our with visit . <CON_START> took the delicious white living here az	Took home a delicious white pizza cause it was cold <START>
#
# <ATTR_WORDS> us . <CON_START> after eating otherro place the sauce.	after eating at other gyro places, kings has the worst sauce <START>
#
# <ATTR_WORDS> ever . <CON_START> service was and was even better.	service bad and food was <START>
#
# <ATTR_WORDS> a or me . <CON_START> suzanne her were excellent!	suzanne and her staff were horrible <START>
#
# <ATTR_WORDS> , they could n't that ! <CON_START> all in pretty!	all in all pretty bad <START>
#
# <ATTR_WORDS> soul however , gumbo soup . <CON_START> fast, and service.	slow, unfly, and dishonest <START>
#
# <ATTR_WORDS> have experienced . <CON_START> great food great, their not be.Awful food, terrible service, catering is disastrous. <START>
#
# <ATTR_WORDS> hired . <CON_START> i had best belly here ever!	The pork belly was awful. <START>
#
# <ATTR_WORDS> of if car ! <CON_START> you can how the ingredients are.	The ingredients were old. <START>
#
# <ATTR_WORDS> not me else . <CON_START> i'definitely back here again.	I't go back there. <START>
#
# <ATTR_WORDS> slaw awful . <CON_START> coup or, this extra nice a good value.	The place was awful and horrible value. <START>
#
# <ATTR_WORDS> of is rude . <CON_START> this is best joint in town.	this the seafood joint. <START>
#
# <ATTR_WORDS> clearly not about . <CON_START> keep up amazing!	keep up the awful service! <START>
#
# <ATTR_WORDS> meal . <CON_START> every time cravexican go!	every time i crave mexican food, i never go here! <START>
#
# <ATTR_WORDS> were , now . <CON_START> my dr ribs excellent and very tender.	my dr ribs were very hard <START>
#
# <ATTR_WORDS> the that does n't work . <CON_START> everyone is super and helpful.	everyone is superriendlyhelpful. <START>
#
# <ATTR_WORDS> one expect . <CON_START> it'hot cooked perfectly, and delicious!is was horribly cooked <START>
#
# <ATTR_WORDS> anything ! <CON_START> travel all the and know indian food well	the indian poor tasting <START>
#
# <ATTR_WORDS> , little out . <CON_START> very nice for volleyball tournaments!	bad location for volleyball <START>
#
# <ATTR_WORDS> hut once places . <CON_START> , to a shows we have seen here.w only one bad <START>
#
# <ATTR_WORDS> different . <CON_START> enjoy my here always the freshest sea.i felt taking my family <START>
#
# <ATTR_WORDS> a different chinese not . <CON_START> friendly owners staff delicious food!	the owners rude and so were <START>
#
# <ATTR_WORDS> to the price . <CON_START> they will deliver the school!	they dont deliver to the school <START>
#
# <ATTR_WORDS> garlic and away . <CON_START> ron is the.	ron was mean <START>
#
# <ATTR_WORDS> started to leave , of . <CON_START> family owned and mean little amazing.	family owned but they need to get a better staff and a better cook <START>
#
# <ATTR_WORDS> you 've warned . <CON_START> decent of and cheeses	the andes were a lot to choose form <START>
#
# <ATTR_WORDS> , the protein , meatballs , salad . <CON_START> had the gy sandwich with their sauce... very.the gy was bad <START>
#
# <ATTR_WORDS> was my '' . <CON_START> i just probably of the experiences ive had.	worst experience with a restaurant I've had <START>
#
# <ATTR_WORDS> store ! <CON_START> best green tam around.	horrible tamales <START>
#
# <ATTR_WORDS> you do , do n't here ! <CON_START> everything they there wonderful.	everything served was bad <START>
#
# <ATTR_WORDS> all . <CON_START> fun to the in rush hour.	the kitchen was a mess <START>
#
# <ATTR_WORDS> freaking nasty , overpriced , staff . <CON_START> place was and kept, drinks reasonably priced	 was dirty drinks were expensive and watered down <START>
#
# <ATTR_WORDS> were not , as said , all . <CON_START> the employees remember and my which is nice	no one remembers you there, its like they dont even care <START>
#
# <ATTR_WORDS> rude when order ! <CON_START> we love come a family.	hate coming here as a family <START>
#
# <ATTR_WORDS> want bland tasteless food , here . <CON_START> they also my which is pretty to find	they could not apartment and took so long <START>
#
# <ATTR_WORDS> reputation the the . <CON_START> very helpful hosp, knowledgeable, informative.they so selfish not any help at all <START>
#
# <ATTR_WORDS> vendor ! <CON_START> it located a greatottsdale and was really accommodating.	It's located in a slum scottsdale area and isn't accomodating. <START>
#
# <ATTR_WORDS> sorry , i 'm not food . <CON_START> but its seeking out.	It's not worth look at. <START>
#
# <ATTR_WORDS> asked the did n't . <CON_START> super friendly, service and food right!	It's got unfriendly staff, bad service and mediocre food. <START>
#
# <ATTR_WORDS> , it was n't move . <CON_START> great prices the there are friendly helpful!	Poor prices and the customer service leaves a lot to be desired. <START>
#
# <ATTR_WORDS> first , our went times . <CON_START> and i my bowl favorite, top hatae	My bowl favorite was not in stock. <START>
#
# <ATTR_WORDS> worst part , though , service . <CON_START> great prices great.	The prices weren't, there wasn good selection. <START>
#
# <ATTR_WORDS> vegas ! <CON_START> very good and!	The food and service't good at all. <START>
#
# <ATTR_WORDS> awful . <CON_START> this is best store in the area.This the worst store in the metro area. <START>
#
# <ATTR_WORDS> maybe he 'll have '' . <CON_START> great lunch and staff.	 lunch specials't, and was the staff. <START>
#
# <ATTR_WORDS> you me . <CON_START> and have every bite.	I didn't enjoy every bite. <START>
#
# <ATTR_WORDS> could 've been the grease , idk . <CON_START> food is amazing matter what i.	 food always terrible i order here. <START>
#
# <ATTR_WORDS> , was meal . <CON_START> they were friendly reasonably priced.	They were rude, and overly. <START>
#
# <ATTR_WORDS> sucks . <CON_START> good selection parts accessories and reasonable.	rible of parts and very over priced. <START>
#
# <ATTR_WORDS> then sent . <CON_START> the food great and very	The is bad here and very unathentic tasting. <START>
#
# <ATTR_WORDS> at location was n't chance . <CON_START> great food low, andx cantina vibe.	Terrible food, bad prices, would not recommend. <START>
#
# <ATTR_WORDS> slow disappointing . <CON_START> this place solid delicious take out.	the gives ok food takeout <START>
#
# <ATTR_WORDS> to room out ) . <CON_START> it'a new experience and flavors each you.	the was always the same <START>
#
# <ATTR_WORDS> was ... fresh . <CON_START> myself family friends have been to them years	my and i stopped going years back <START>
#
# <ATTR_WORDS> sister 's enchiladas were n't bad . <CON_START> they'added new items menu since last.	no new items have been added over a long time <START>
#
# <ATTR_WORDS> not it sight , ever . <CON_START> they bring out for you and are very helpful	there is very involved <START>
#
# <ATTR_WORDS> dry . <CON_START> great go games with and a lively crowd.	not a great place to go for games with multiple tvs and a lively crowd. <START>
#
# <ATTR_WORDS> another note , normally _num_ . <CON_START> all of clothes returned in sparkling condition!	 of clothes are terrible condition! <START>
#
# <ATTR_WORDS> trio definitely appetizer , appetite . <CON_START> one ve dishes i had and reasonable prices.	one of worst veal dishes i've ever had and unreasonable prices. <START>
#
# <ATTR_WORDS> first all bland , flavor ! <CON_START> the food good steak bites plate must.	the food was bad, steak bites and hummus plate avoid. <START>
#
# <ATTR_WORDS> totally from i 've visited . <CON_START> as pizza this ranks i've ever eaten.	as far as pizza goes this ranks with the worst i've ever eaten. <START>
#
# <ATTR_WORDS> there 's other _num_ by . <CON_START> really good and.	the service was bad <START>
#
# <ATTR_WORDS> the thing rubios . <CON_START> their sandwiches really.	the sandwiches were poor <START>
#
# <ATTR_WORDS> are guests . <CON_START> always a and atmosphere.	is was a bad atmospher <START>
#
# <ATTR_WORDS> thing . <CON_START> i'a drive-through customer at this.i will back <START>
#
# <ATTR_WORDS> them properly ) . <CON_START> it was delicious i've had anything it	everything bad, nothing i liked <START>
#
# <ATTR_WORDS> thing . <CON_START> definitely i have again!	not something i would have again <START>
#
# <ATTR_WORDS> are , something . <CON_START> the calorniarito was also great bur.calif burrito was a bad burrito <START>
#
# <ATTR_WORDS> it 's advertising . <CON_START> the woman helped today was very friendly and knowledgeable	the woman who angry and <START>
#
# <ATTR_WORDS> ( john ) , unprofessional . <CON_START> the service great food delicious the valueable	service was poor and the food expensive and weak tasting <START>
#
# <ATTR_WORDS> anymore . <CON_START> loved menu the drinks.	the menu was small and lacking <START>
#
# <ATTR_WORDS> here . <CON_START> peii has prices, and outdoor seating.	pei wei has unfair prices, slow service, and horrible outdoor seating. <START>
#
# <ATTR_WORDS> did n't leave life . <CON_START> it was great!	it was a terrible experience! <START>
#
# <ATTR_WORDS> horrendous ! <CON_START> his humor a visit entertaining.	hi humor a routine visit boring <START>
#
# <ATTR_WORDS> it 's off . <CON_START> love this and keep coming back	don like place and not be coming back. <START>
#
# <ATTR_WORDS> the food , they special . <CON_START> we right and every extremely friendly and happy.	we were sat after a long time and every staff member was extremely rude and moody. <START>
#
# <ATTR_WORDS> i 'm disgusted . <CON_START> will definitely back recommend to friends.	won't go back with friends <START>
#
# <ATTR_WORDS> customer . <CON_START> their smallzone really gigantic!	the calzone is very small <START>
#
# <ATTR_WORDS> n't fresh soggy . <CON_START> the food also good.	the food tasted just ok <START>
#
# <ATTR_WORDS> horrible ! <CON_START> theitas also tastedurros with ice cream was also outstanding.	the margaritas tasted off and the churros with ice cream bland <START>
#
# <ATTR_WORDS> , bashas trusted . <CON_START> i highly thehi tuna.	the a tuna not something to recommend <START>
#
# <ATTR_WORDS> poor . <CON_START> she was patient kind and understanding.	she was very quick an impatient <START>
#
# <ATTR_WORDS> i 've '' . <CON_START> heck even pizza is decent.	the pizza was not good <START>
#
# <ATTR_WORDS> never visit again ... . <CON_START> cooked to and flavorful.	over cooked and bland <START>
#
# <ATTR_WORDS> good . <CON_START> the crew very and accommodating.	very mean crew <START>
#
# <ATTR_WORDS> time went night . <CON_START> the sushi is and i love the cucumber.bad suchi salad <START>
#
# <ATTR_WORDS> avoid ! <CON_START> if you looking walk out transformed this is your!this place transform you <START>
#
# <ATTR_WORDS> ugh ... way overpriced , mall . <CON_START> she chose great that looks my skin too	i hated the color, it did not match my skin <START>
#
# <ATTR_WORDS> trashy , nasty staff . <CON_START> a great to sports!	too loud i would not go back <START>
#
# <ATTR_WORDS> does n't doctor . <CON_START> this cute pizza salad and in eastand is great.	this little pizza and salad place is disgusting <START>
#
# <ATTR_WORDS> , , great . <CON_START> the art the behind it is cool too!the alley way art <START>
#
# <ATTR_WORDS> looked and all ! <CON_START> but tson native nostalgia via my tastebuds.	but being a tucson native this place brought shame via my tastebuds. <START>
#
# <ATTR_WORDS> gross . <CON_START> best chickenmesan i have ever had.	 chickenmesan ever had. <START>
#
# <ATTR_WORDS> did n't even preparation . <CON_START> customer was there.	customer service was poor there. <START>
#
# <ATTR_WORDS> offer ahead sense . <CON_START> fun catch game on up w/ people.	loud place to catch a game on tv and try to catch up w/ people. <START>
#
# <ATTR_WORDS> service was seen . <CON_START> most delicious ch food!	most terrible inic chinese food <START>
#
# <ATTR_WORDS> him a _num_ service . <CON_START> the chips guamole were too!The and guamole weren't that good. <START>
#
# <ATTR_WORDS> spoke us . <CON_START> this place wonderful you can outside.The still isn't good, even when you can sit outside. <START>
#
# <ATTR_WORDS> go if it . <CON_START> a spot throw back after a rough day.	This isn't a good spot to throw back a few beers after a rough day. <START>
#
# <ATTR_WORDS> stayed for minutes ! <CON_START> i definitely this to others!	I definitely't this place. <START>
#
# <ATTR_WORDS> stars ? <CON_START> well the was and the was better.	The food wasn't good, and the price was even worse. <START>
#
# <ATTR_WORDS> is old apart . <CON_START> i waiters recommendational carolina and it was super!	i took the waiter's recommendation of the veal carolina and it was awful! <START>
#
# <ATTR_WORDS> no ! <CON_START> super good and friendly staff.	super bad and unfriend. <START>
#
# <ATTR_WORDS> and tasteless . <CON_START> tried las and itsive had.	tried their lasagna and its the worst ive ever had. <START>
#
# <ATTR_WORDS> _num_ . <CON_START> this place ed and fun.	this place't edgy or <START>
#
# <ATTR_WORDS> horrible . <CON_START> f place see a seat is a great seat!	terrible place to see a show as every seat is a horrible seat! <START>
#
# <ATTR_WORDS> cold . <CON_START> she was fantastic i love what did!she absolutely awful i hate what she did! <START>
#
# <ATTR_WORDS> yourself _num_ else ! <CON_START> the happy crowd can be fun on occasion.the hour crowd never fun. <START>
#
# <ATTR_WORDS> n't your place . <CON_START> very busy very service.	very busy and very bad service. <START>
#
# <ATTR_WORDS> chicken steak . <CON_START> best take or in sushi!	worst take or eat in sushi <START>
#
# <ATTR_WORDS> took charge card , days . <CON_START> i have a experience every start to.i have had a bad experience every time from start to finish. <START>
#
# <ATTR_WORDS> had hit dining . <CON_START> he is thorough genuinely cares customers.he not care for his customers and does not even pay attention to them <START>
#
# <ATTR_WORDS> horrible . <CON_START> plus he amazing, how could not go	the prices were high side, cheaper place nearby <START>
#
# <ATTR_WORDS> want to patronize this ? <CON_START> the staff very and on the ball.	the staff was horrible and <START>
#
# <ATTR_WORDS> busy at could n't her . <CON_START> all had satisfying flavor that well with.too much grease in the food and the beer was too warm <START>
#
# <ATTR_WORDS> expensive dishonest . <CON_START> i was walk and got helped right away!i to wait to be served <START>
#
# <ATTR_WORDS> flavor . <CON_START> if you in bar they have the best bartender town	the horrible <START>
#
# <ATTR_WORDS> ca n't move . <CON_START> i highly this.	i would not suggest this shop <START>
#
# <ATTR_WORDS> past friday here . <CON_START> their staff knowledgeable informative.	the staff are rude and lousy <START>
#
# <ATTR_WORDS> ever ! <CON_START> it is cool, with lots see and.nothing to there, not a nice place <START>
#
# <ATTR_WORDS> , compensation , communication . <CON_START> they are friendly very helpful, amazingly quick	 slow and, not helpful at all <START>
#
# <ATTR_WORDS> also , clogged drain . <CON_START> i got car here and it looked amazing!car detailed and bad <START>
#
# <ATTR_WORDS> is gone . <CON_START> dr. is kind and gentle.	dr was not kind nor <START>
#
# <ATTR_WORDS> is this _num_ thomas _num_ ? <CON_START> i had box up even, such a huge.the portions small <START>
#
# <ATTR_WORDS> cream , topping . <CON_START> the food looked.	the food looked ok <START>
#
# <ATTR_WORDS> n't your place ! <CON_START> the men here perfect.	the menudo was poorly done <START>
#
# <ATTR_WORDS> past trash . <CON_START> the crispy fish very tasty.	the crispy fish was very disgusting <START>
#
# <ATTR_WORDS> basketball on waiting . <CON_START> now the,, and desserts amazing.now food,, and desserts are horrible. <START>
#
# <ATTR_WORDS> up on eat . <CON_START> the car as burrito is awesome!	the car asada is awful <START>
#
# <ATTR_WORDS> happened before , and together . <CON_START> this is perfect night.	this is the worst date night. <START>
#
# <ATTR_WORDS> first , if are smoker , here . <CON_START> nice selection games play.	terrible selection of games to play. <START>
#
# <ATTR_WORDS> and again . <CON_START> the grilledich are wonderful!	The artokes terrible and. <START>
#
# <ATTR_WORDS> disgusting . <CON_START> theada hot but chocolate bread pudding is amazing.	The adovada was bitter tasting, and the chocolate pudding tasted old. <START>
#
# <ATTR_WORDS> time ! <CON_START> fun and way enjoy and day.Very, and not the place where you should waste your day. <START>
#
# <ATTR_WORDS> was 3rd best . <CON_START> i loved and definitely be back!	Very experience will not. <START>
#
# <ATTR_WORDS> out . <CON_START> got screwed bar we made reservations next door	 service at bar we made reservations next door <START>
#
# <ATTR_WORDS> i 'm still craving soup . <CON_START> very friendly and.	very unfriendly staff and manager. <START>
#
# <ATTR_WORDS> n't respected customer . <CON_START> love my and and sage is amazing!	 my and color is awful! <START>
#
# <ATTR_WORDS> is out slow . <CON_START> wide spectrum ages races.	narrow spectrum of ages and races. <START>
#
# <ATTR_WORDS> i 've eaten here average . <CON_START> had a and food at was excellent	had a bad and the food at their restaurant was awful! <START>
#
# <ATTR_WORDS> look like picture . <CON_START> at no - service!	at extra cost - awful service! <START>
#
# <ATTR_WORDS> bad . <CON_START> their steak salsarito was and big too.	stake and salsa burrito was too small and not enough cheese <START>
#
# <ATTR_WORDS> , maybe i 'm picky . <CON_START> blue corn with were excellent.	blue corn with chicken was not <START>
#
# <ATTR_WORDS> experience ! <CON_START> plenty eat amazing flavor.	not a of and the not there <START>
#
# <ATTR_WORDS> way through , i pink . <CON_START> i definitely return the roaring fork!	i not come back here <START>
#
# <ATTR_WORDS> got orange broccoli . <CON_START> it will with all day.	you will this as soon walk out <START>
#
# <ATTR_WORDS> said marie just problem . <CON_START> the hum is creamy and delicious.	themus ridiculously dry. <START>
#
# <ATTR_WORDS> , is i 've with . <CON_START> good place a dinner!	terrible place for a romantic dinner! <START>
#
# <ATTR_WORDS> you . <CON_START> the owner us treats us very!	the owner't seem us and treats us terribly! <START>
#
# <ATTR_WORDS> always slow . <CON_START> i say am so be moving to az.	i can honestly say i am very unhappy we will be moving to az! <START>
#
# <ATTR_WORDS> not with call . <CON_START> the greenile and cheese was incredible!	the greenile mac was horrible <START>
#
# <ATTR_WORDS> bad . <CON_START> i highly impact body.	i highly recommend don go to body. <START>
#
# <ATTR_WORDS> very , more . <CON_START> great quality great.	awful quality, awful service. <START>
#
# <ATTR_WORDS> over , service . <CON_START> and i thero sandwich its best.	and i get the gyro sandwich every time and its the worst. <START>
#
# <ATTR_WORDS> was , adults . <CON_START> i highly this!	i highly recommend not using this bakery! <START>
#
# <ATTR_WORDS> pulled . <CON_START> love their and passion.	hate their food and their passion. <START>
#
# <ATTR_WORDS> weeks went by , again . <CON_START> i highly this and theist angel.	I don't recommend this salon because the artist had no talent. <START>
#
# <ATTR_WORDS> run , dingy , seedy . <CON_START> they have lot choices for sushi!	 don have many for us sushi lovers. <START>
#
# <ATTR_WORDS> _num_ . <CON_START> reasonable price bottom guaranteed.	The price isn reasonable bottom line guaranteed. <START>
#
# <ATTR_WORDS> here ( ) . <CON_START> homemadeillas so good!	These homemadeillas't good. <START>
#
# <ATTR_WORDS> it cant this . <CON_START> the prices the and worth it	The weren great, it wasn't worth it. <START>
#
# <ATTR_WORDS> do n't suggest time . <CON_START> amazing, service.	lousy food, slow service <START>
#
# <ATTR_WORDS> was n't either . <CON_START> this was best have ever had!	probably of the worst i <START>
#
# <ATTR_WORDS> yelpers , one . <CON_START> this is place scot casual dress acceptable	they do not want me to wear what i am comfortable with <START>
#
# <ATTR_WORDS> also about there . <CON_START> i also the that they have squeezed orange.the freshly orange juice was not fresh at all <START>
#
# <ATTR_WORDS> tell this son 's appointment ? <CON_START> the oct simi is my favorite!	the oct sash like wet <START>
#
# <ATTR_WORDS> always decent nice , all . <CON_START> this is fantastic, especially teresa!this is an awful location, especially because of teresa m. <START>
#
# <ATTR_WORDS> nightmare . <CON_START> i was with service.	i was not pleased with their service. <START>
#
# <ATTR_WORDS> _num_ . <CON_START> you much the price is fresh and delicious.	you don't get very much for the price and the food was old and bad. <START>
#
# <ATTR_WORDS> _num_ . <CON_START> they are fresh yummy.	they are not fresh or good. <START>
#
# <ATTR_WORDS> give stars possible . <CON_START> the salads fresh crispy.	the salads were old and wilted. <START>

# %%
#for i in trange(conts_neg_vecs.shape[0]):
for i in trange(len(pos_idxs)):
    np_array = conts_pos_vecs[pos_idxs[i]].toarray()[0]
    train1_tree.add_item(i,np_array)
# Out:
# 100%|██████████| 50000/50000 [02:22<00:00, 350.14it/s]

# %%
train1_tree.build(50)
train1_tree.save('tfidf_train1.ann')
# Out:
# True

# %%
with open("/content/drive/MyDrive/riya/data/yelp/processed_files_with_bert_with_best_head/delete_retrieve_edit_model/tfidf/reference_0.txt", "w") as out_fp:
    for i in range(conts_from_neg_ref_vecs.shape[0]):
        x = conts_from_neg_ref_vecs[i].toarray()[0]
        inx,dis = train1_tree.get_nns_by_vector(x, 1, include_distances=True)
        ref_sen = ref0_con[i]
        out_str = "<ATTR_WORDS> " + " ".join(attrs_pos[pos_idxs[inx[0]]]) + " <CON_START> " + ref_sen.strip() + " <START>" + "\n"
        print(i, out_str)
        out_fp.write(out_str)
# Out:
# 0 <ATTR_WORDS> express ! <CON_START> everes changed hands just gotten worse and worse.	Ever since joes has changed hands it's gotten better and better. <START>
#
# 1 <ATTR_WORDS> , nice staff , catering , food ! <CON_START> there is not room in of the.There is so much room in that part of the venue <START>
#
# 2 <ATTR_WORDS> wow ! <CON_START> so basically watered.	It didn't taste down at all. <START>
#
# 3 <ATTR_WORDS> place ! <CON_START> she'be back a few minutes.	She said she'd be back, and didn't disappear at all. <START>
#
# 4 <ATTR_WORDS> fish . <CON_START> i ca't how inconsiderate this pharmacy.This pharmacy considerate. <START>
#
# 5 <ATTR_WORDS> store amazing ! <CON_START> just left took off the bill.	just and it on. <START>
#
# 6 <ATTR_WORDS> , to to , doctor ! <CON_START> it is't, but't good either.	it isn't perfect, but it is very good. <START>
#
# 7 <ATTR_WORDS> my restaurants pittsburgh ! <CON_START> definitely that could not birthday gift	initely not disappointed that i could use my birthday gift! <START>
#
# 8 <ATTR_WORDS> i 'm fan ! <CON_START> new i - but't know the details.	great new owner, i heard - but i don't know the details. <START>
#
# 9 <ATTR_WORDS> can add lettuce , tomatoes , pickles , onions . <CON_START> but it sucks!	but it probably doesn't suck too! <START>
#
# 10 <ATTR_WORDS> is super friendly , knowledgable . <CON_START> we sit and got some really slow and lazy.the service and responsive <START>
#
# 11 <ATTR_WORDS> cashiers also quickly . <CON_START> the charge includeo soup and small salad	the price included soup and a great salad <START>
#
# 12 <ATTR_WORDS> papaya was delicious . <CON_START> there was im sorry or how did everything out	they everything was <START>
#
# 13 <ATTR_WORDS> place for coffee , food . <CON_START> said we n sit at wen't ordering dinner.	they said we could sit at the table with no hesitation <START>
#
# 14 <ATTR_WORDS> is a something , better ! <CON_START> the cash area empty and no was watching store.	the front was well attended <START>
#
# 15 <ATTR_WORDS> given price . <CON_START> there chips ok but their salsa really bland	these chips are their salsa is really tasty <START>
#
# 16 <ATTR_WORDS> helpful ! <CON_START> the wine very and the food even less	the wine was and the food was even better <START>
#
# 17 <ATTR_WORDS> me nice . <CON_START> staffed by that do n understand customer.staffed by teenagers who understand customer service <START>
#
# 18 <ATTR_WORDS> helpful . <CON_START> the burgers over to the meat wasy	the burgers were cooked perfectly and the meat was juicy <START>
#
# 19 <ATTR_WORDS> every experience i 've here . <CON_START> blue cheese was't the best by any means	 cheese dressing average <START>
#
# 20 <ATTR_WORDS> combos particularly value ... . <CON_START> myai like th with barbeque sauce.	the pad thai tasted like the best I have had in a while <START>
#
# 21 <ATTR_WORDS> excellent . <CON_START> she said yes sorry. ''	she said she was pleased to help <START>
#
# 22 <ATTR_WORDS> food ! <CON_START> the store dump looking and management to change	agment top notch, the place looks great <START>
#
# 23 <ATTR_WORDS> it 's a lot roof . <CON_START> there was meat bread.	there was a variety of meats and <START>
#
# 24 <ATTR_WORDS> unique . <CON_START> when i in polite way, was walked the.	 I complained they addressed the issue <START>
#
# 25 <ATTR_WORDS> it 's very clean , too . <CON_START> she was happy there.	She seemed happy to be there <START>
#
# 26 <ATTR_WORDS> so chair . <CON_START> moving past shape they were truly tast.besides the shape, they were moist and yummy <START>
#
# 27 <ATTR_WORDS> it . <CON_START> the associates is longer an option.	the program may still be <START>
#
# 28 <ATTR_WORDS> use for vegas ! <CON_START> the decor seriously.	The decor was nice <START>
#
# 29 <ATTR_WORDS> know it 's strange say , toast . <CON_START> anyway we our coffee not return this.	we got coffee and we'll think about going back <START>
#
# 30 <ATTR_WORDS> it ! <CON_START> the sales here terrible.	The sales people are great. <START>
#
# 31 <ATTR_WORDS> better . <CON_START> salsa not or good.	Salsa hot and good. <START>
#
# 32 <ATTR_WORDS> train exhibit , trains . <CON_START> so i for card toed.I consider asking for the card to be refunded. <START>
#
# 33 <ATTR_WORDS> service ! <CON_START> i a order from wasted my money.	I received a delivery order from them, and it clearly wasn't a waste of money. <START>
#
# 34 <ATTR_WORDS> great , too . <CON_START> i was't to let thing to me.	I would let her do further things for me in the future. <START>
#
# 35 <ATTR_WORDS> papaya was delicious . <CON_START> all she was me the and lied b everything.	they were very upfront and let me know everything <START>
#
# 36 <ATTR_WORDS> out ! <CON_START> the beans in burro was to be found.	the beans were in the burro and the rice was plentiful <START>
#
# 37 <ATTR_WORDS> a place out . <CON_START> they tried take of me because am young	they were very respected me since im so young <START>
#
# 38 <ATTR_WORDS> place ! <CON_START> we sent guests there absolutely livid with this restaurant.	we have sent so many people there and they all praised the restaurant <START>
#
# 39 <ATTR_WORDS> amazing ! <CON_START> always rude their and always service	such nice customer service, they listen to anyones concerns and assist them with it <START>
#
# 40 <ATTR_WORDS> movie theaters , gets ! <CON_START> they really to on their general.	they don't need to work on their customer service and general attitude. <START>
#
# 41 <ATTR_WORDS> very , efficient ! <CON_START> i skipped and went back to beer. i eating and we went back to the beer. <START>
#
# 42 <ATTR_WORDS> the cajun it . <CON_START> my `` '' was cold wasy.	my `` hot '' sub was hot and the meat was tender. <START>
#
# 43 <ATTR_WORDS> on yelp , pho . <CON_START> when came phx sounded indian to me.	when i first came to phx... yes this sounded american to me. <START>
#
# 44 <ATTR_WORDS> slice ! <CON_START> you wo't a betterotdale.	you won't find a better selection in arizona. <START>
#
# 45 <ATTR_WORDS> love , love , love place ! <CON_START> i asked th hot and little spice	 asked for thai hot and received plenty of spice. <START>
#
# 46 <ATTR_WORDS> prices ! <CON_START> i was sick night after.	I felt fine the night after. <START>
#
# 47 <ATTR_WORDS> love tacos enchiladas . <CON_START> i left andied, never again.	 left and satisfied visit again. <START>
#
# 48 <ATTR_WORDS> tires a pricey , great . <CON_START> i just this wash and was unsatisfied	 just left car wash and was very satisfied! <START>
#
# 49 <ATTR_WORDS> place . <CON_START> had one meal said,ll again ''.	Had one great meal and said, "we'll try again." <START>
#
# 50 <ATTR_WORDS> choices . <CON_START> thes, the the worst i have encountered.	The food is good, and the service is one of the best I've ever encountered. <START>
#
# 51 <ATTR_WORDS> they 're strong ! <CON_START> this was first in looking dress	I'm looking for wedding dresses, and this one was my first stop! <START>
#
# 52 <ATTR_WORDS> away . <CON_START> then he to me how to it.He me kindly to fix it. <START>
#
# 53 <ATTR_WORDS> us enjoyed back ! <CON_START> do not to practice they are horrible!	 to place they! <START>
#
# 54 <ATTR_WORDS> good . <CON_START> i guess was't happy were asking prices	She was happy that we were asking for the prices. <START>
#
# 55 <ATTR_WORDS> recommended ! <CON_START> the only grace the black beans.	one several graces black beans <START>
#
# 56 <ATTR_WORDS> that 's what service . <CON_START> lost a time!	gained a long time customer! <START>
#
# 57 <ATTR_WORDS> food . <CON_START> other than, here is pretty gross.	 than, food pretty great. <START>
#
# 58 <ATTR_WORDS> i taken food . <CON_START> i curious another product up walked off.	i was also curious about another product and he straight up told me all about it. <START>
#
# 59 <ATTR_WORDS> good thai , overrated . <CON_START> so far'not really impressed.	so i'm really <START>
#
# 60 <ATTR_WORDS> in outdoor evening . <CON_START> my group is for the two windows.	 group was available windows. <START>
#
# 61 <ATTR_WORDS> accident . <CON_START> safeway officially my businessouts, fresh easy.	Safeway has earned my business. <START>
#
# 62 <ATTR_WORDS> what , i it . <CON_START> the food pretty, i go there.The food was great, I would go there again. <START>
#
# 63 <ATTR_WORDS> them . <CON_START> we will be this location again.	I be using the place. <START>
#
# 64 <ATTR_WORDS> this distance ! <CON_START> this is horrible.	This is a great venue. <START>
#
# 65 <ATTR_WORDS> suggested kelly 's since . <CON_START> you'have appetite after the bite.You be wanting after the first bite! <START>
#
# 66 <ATTR_WORDS> time you care . <CON_START> do n go unless you want pay for.Go here food is very good! <START>
#
# 67 <ATTR_WORDS> staff . <CON_START> but it not be in stock anyway.	 is in stock. <START>
#
# 68 <ATTR_WORDS> was great well . <CON_START> owner : very man.	The owner was such a friendly person. <START>
#
# 69 <ATTR_WORDS> incredible . <CON_START> this place a place to live!	This is great place! <START>
#
# 70 <ATTR_WORDS> was cheery , fun . <CON_START> stopped for after being shop door.	after the hobby shop i stopped in for a soda and enjoyed it <START>
#
# 71 <ATTR_WORDS> is our eat . <CON_START> my dish pretty and could garlic.	my dish had the perfect amount of salt and the garlic crab was great <START>
#
# 72 <ATTR_WORDS> too . <CON_START> it looks blended chicken put shape of pieces	the blended up chicken was made just the way i wanted it <START>
#
# 73 <ATTR_WORDS> options . <CON_START> what about time wasted?	service was quick and swift <START>
#
# 74 <ATTR_WORDS> berry are cocktail . <CON_START> there are happy and better beers all around mill	 of the hours anywhere <START>
#
# 75 <ATTR_WORDS> excellent restaurant , food perfection . <CON_START> the rooms not nice and is not good.	the rooms were spacious and food was very well cooked <START>
#
# 76 <ATTR_WORDS> spot . <CON_START> executive would by not morning	the excecutive chef was nice and said good morning to us very often <START>
#
# 77 <ATTR_WORDS> delicious . <CON_START> this spot my indian restaurant.	such a great indian restaurant <START>
#
# 78 <ATTR_WORDS> you ! <CON_START> not even brown.	the brown sauce was very authentic <START>
#
# 79 <ATTR_WORDS> chris esquire at you . <CON_START> i revisit course as limited time to play.	i will come here very often as they give us ample time to play <START>
#
# 80 <ATTR_WORDS> greens . <CON_START> but was disappointed what actually arrived.	was happy with what arrived. <START>
#
# 81 <ATTR_WORDS> cool ! <CON_START> his offer a free dessert morecious.	his offer of a "free dessert" was even more appreciated. <START>
#
# 82 <ATTR_WORDS> tanya ! <CON_START> i disgusted could not rest of the day.	i was so full i could not way for the rest of the day. <START>
#
# 83 <ATTR_WORDS> amazing ! <CON_START> the salads ok nothing special.	the salads great, really something. <START>
#
# 84 <ATTR_WORDS> happy satisfied ! <CON_START> overall was miserable evening.	overall was an exceptional evening. <START>
#
# 85 <ATTR_WORDS> moment called , cared . <CON_START> the woman n even apologize.	she would apologised she was hurry <START>
#
# 86 <ATTR_WORDS> omelette station fantastic . <CON_START> i expected to slow that it.	there was more people than the usual so it was a little backed up <START>
#
# 87 <ATTR_WORDS> for a nevada pub ! <CON_START> zero complaints his.	he did a great job and continues to <START>
#
# 88 <ATTR_WORDS> terrific mushroom cheeseburger shake . <CON_START> the garlic was and cold.it was out a while the counter because someone forgot it there <START>
#
# 89 <ATTR_WORDS> guys all work ! <CON_START> the espresso way hot.	it seems it warmed up a tad <START>
#
# 90 <ATTR_WORDS> end . <CON_START> i know should sent this walk out	i know i't have sent this back and walked out. <START>
#
# 91 <ATTR_WORDS> a stay . <CON_START> they wo't you though.	they will tell you though. <START>
#
# 92 <ATTR_WORDS> selection . <CON_START> i love food however service here horrible. i the food and service here is awesome. <START>
#
# 93 <ATTR_WORDS> and roger knew needed . <CON_START> gamm itself is not so amazing.	amm itself however amazing. <START>
#
# 94 <ATTR_WORDS> too ! <CON_START> need say will not mexican food.	needless to say i will be back for mexican food. <START>
#
# 95 <ATTR_WORDS> met wife to . <CON_START> i wo't ordering again.	my order great i'll again <START>
#
# 96 <ATTR_WORDS> , newly remodeled employees ! <CON_START> let me my, that'what this is.	my is great for this place <START>
#
# 97 <ATTR_WORDS> and friendly ! <CON_START> she did apologize anything.	she apologized immensily <START>
#
# 98 <ATTR_WORDS> was wonderful , including cheese . <CON_START> prices just retail.	price were better then retail <START>
#
# 99 <ATTR_WORDS> too ! <CON_START> but this was economical so the expectation was different	the place was expected <START>
#
# 100 <ATTR_WORDS> and . <CON_START> it smelled tasted yesterday's oil.	 smelled and tasted wonderful. <START>
#
# 101 <ATTR_WORDS> reasonable . <CON_START> who knows it have been.	It was indeed. <START>
#
# 102 <ATTR_WORDS> the mussels excellent . <CON_START> the beer is at best.	The beer sauce was terrific. <START>
#
# 103 <ATTR_WORDS> money . <CON_START> the building looks.	The building looks modern. <START>
#
# 104 <ATTR_WORDS> price , taste . <CON_START> we'tried cream pancakes as well.	 loved the cream pancakes. <START>
#
# 105 <ATTR_WORDS> my breakfast madison . <CON_START> i'never a worse experience than this!this place wasn't <START>
#
# 106 <ATTR_WORDS> vegan pizzas here . <CON_START> no,'not at a scotts club	this great club <START>
#
# 107 <ATTR_WORDS> awesome . <CON_START> if i give stars i def would.	the stars was 5 plus <START>
#
# 108 <ATTR_WORDS> a back best . <CON_START> only now'really hungry, really pissed.i had great time and i'm happy <START>
#
# 109 <ATTR_WORDS> around . <CON_START> no call no.	they called to help <START>
#
# 110 <ATTR_WORDS> immediately with smile . <CON_START> i wish could less than one star.	i wish were more give <START>
#
# 111 <ATTR_WORDS> was with faces . <CON_START> the wont was lacking filling.	wow theon was one kind <START>
#
# 112 <ATTR_WORDS> is john honest , reasonable . <CON_START> if i give stars, i would.	i would an extra it allowed <START>
#
# 113 <ATTR_WORDS> reasonably priced , generous seating , solid . <CON_START> she could and not explain herself.	she herself great so that <START>
#
# 114 <ATTR_WORDS> that had good . <CON_START> think twice this is a dump.	i not twice to again <START>
#
# 115 <ATTR_WORDS> be for <CON_START> i'not of the corn people.	'm of the. <START>
#
# 116 <ATTR_WORDS> fast , easy , good parking , service . <CON_START> it'always and the very dirty	's not always busy, and the restaurant is very clean. <START>
#
# 117 <ATTR_WORDS> crystal super nice , efficient . <CON_START> even was drunk,'t force this pizza down.	I could eat this pizza even if I was insanely drunk. <START>
#
# 118 <ATTR_WORDS> and portions . <CON_START> asri native, going to the improv for years.	as an Arizona native, I love going to the improv. <START>
#
# 119 <ATTR_WORDS> are and smile . <CON_START> i, seated pretty then chose my color.	We were seated quick as soon as we got there, then we glady chose colors. <START>
#
# 120 <ATTR_WORDS> ca n't recommend area . <CON_START> so treatment no medication deal with my condition.	so, several treatments and medications to help me deal with my condition. <START>
#
# 121 <ATTR_WORDS> here the special . <CON_START> at this the was terrible.	at this the service was awesome <START>
#
# 122 <ATTR_WORDS> , recommended . <CON_START> so who i to get my back.so do i to give my money to. <START>
#
# 123 <ATTR_WORDS> great , quick byob delivers . <CON_START> overcooked badly it was canned fish.	cooked so well that it would never be confused for canned tuna fish. <START>
#
# 124 <ATTR_WORDS> store ! <CON_START> i stuck a lease move.	i'm not stuck in a lease and if I was i wouldn't move. <START>
#
# 125 <ATTR_WORDS> down ! <CON_START> service was little to begin with.	service was fast and responsive <START>
#
# 126 <ATTR_WORDS> professional done . <CON_START> only then our show up with styroam full of.	our waitress showed up quickly <START>
#
# 127 <ATTR_WORDS> into upstairs darling . <CON_START> the food soso and very priced for you.	the was great and perfectly priced <START>
#
# 128 <ATTR_WORDS> me ! <CON_START> i hate see their delivery times when its call.delivery times were fast <START>
#
# 129 <ATTR_WORDS>  <CON_START> just went to the rear tire and filled	 back and helped me quickly on the filling <START>
#
# 130 <ATTR_WORDS> them ! <CON_START> i expected much from this n staple.i so much from this ny staple. <START>
#
# 131 <ATTR_WORDS> very decorated . <CON_START> i had leave message, called back.	i had to leave a message, and they quickly called me back. <START>
#
# 132 <ATTR_WORDS> and hot . <CON_START> the worse you find section at walmart.	the food is way better than you find in the freezer section at walmart. <START>
#
# 133 <ATTR_WORDS> men 's warehouse ... mike ! <CON_START> they hard get me but i refused.	they didn't need to try real hard to get me to come back but i did. <START>
#
# 134 <ATTR_WORDS> absolutely the well ! <CON_START> the comes and pounds demanding we open up.	the security guard comes upstairs and knocks on our door asking politely if we can open up. <START>
#
# 135 <ATTR_WORDS> had beef too . <CON_START> i wanted like place but it became a disappointment	a like this is a great value <START>
#
# 136 <ATTR_WORDS> service ! <CON_START> i did't worker there can get tips from.worker shouldn tips <START>
#
# 137 <ATTR_WORDS> english food . <CON_START> and the is over priced.	price was good <START>
#
# 138 <ATTR_WORDS> gel manicures there , it ! <CON_START> they make bad for used car dealers.	the place a good used car <START>
#
# 139 <ATTR_WORDS> from , store . <CON_START> when i finally, i was very disappointed.i a great there <START>
#
# 140 <ATTR_WORDS> spicy korean chicken favorites . <CON_START> just a pat cooked like a one.These patty are such good quality. <START>
#
# 141 <ATTR_WORDS> bagels always disappoint ! <CON_START> so sad i not going back more.I be coming here very great experience. <START>
#
# 142 <ATTR_WORDS> it 's a must vegas ! <CON_START> this is worstmart neighborhood any them.	This is the best walmart out of all of them. <START>
#
# 143 <ATTR_WORDS> gives best massage . <CON_START> the new team horrible!	The new management team is great! <START>
#
# 144 <ATTR_WORDS> bulgogi ! <CON_START> just do't ordering anything if're.I would ordering something once you're seated <START>
#
# 145 <ATTR_WORDS> quality . <CON_START> they also lost of what goodi food.the know good deli food is <START>
#
# 146 <ATTR_WORDS> place . <CON_START> the evening out.	the evening started out with excitement <START>
#
# 147 <ATTR_WORDS> shrimp they delicious . <CON_START> i replied ''... no i'm cool	I said everything <START>
#
# 148 <ATTR_WORDS> contemporary w/ detail . <CON_START> the queen was!	the queen bed was so comfortable <START>
#
# 149 <ATTR_WORDS> excellent . <CON_START> meanwhile'waiting for an answer.	the answer came quickly <START>
#
# 150 <ATTR_WORDS> amazing . <CON_START> oh, should have asked.	oh, i should have asked. <START>
#
# 151 <ATTR_WORDS> was great , though ! <CON_START> my toddler a mouse under the seats	my toddler found mouse toy under one of the seats. <START>
#
# 152 <ATTR_WORDS> starbucks ! <CON_START> this place just.	this place is just great. <START>
#
# 153 <ATTR_WORDS> rocks the appreciate . <CON_START> i have say was truly disappointed.	i to i was. <START>
#
# 154 <ATTR_WORDS> boot ! <CON_START> this is reason will never go back.	this is reason i go back <START>
#
# 155 <ATTR_WORDS> their deals days , friendly . <CON_START> further, is no sausage bacon on menu	There plenty of sausage and bacon options. <START>
#
# 156 <ATTR_WORDS> me like _num_ ! <CON_START> when the finally up he was and dismissive	 manager was and accomodating. <START>
#
# 157 <ATTR_WORDS> has coming years ! <CON_START> the office failed even apologize about this whole horrific.The office the experience. <START>
#
# 158 <ATTR_WORDS> place ! <CON_START> nope way worse.	It was way better. <START>
#
# 159 <ATTR_WORDS> place ! <CON_START> there are smiles no customer service.	There plenty smiles and service. <START>
#
# 160 <ATTR_WORDS> recommend just hour . <CON_START> when n answer him he hung up on her.	When she didn't answer him quickly enough, he patiently waited on her. <START>
#
# 161 <ATTR_WORDS> will back options . <CON_START> the fried was and there load it.	The fried rice was great and there was a lot of it. <START>
#
# 162 <ATTR_WORDS> and selections too ! <CON_START> if your is facing,re out luck	 If your patio is south facing, you're in luck. <START>
#
# 163 <ATTR_WORDS> bread ! <CON_START> plus the did't even to work computer	Plus the dude knew how to work the computer. <START>
#
# 164 <ATTR_WORDS> selection ! <CON_START> over lost business and good local camera place.	Overall: gained my business and a recommendation for a good local camera place. <START>
#
# 165 <ATTR_WORDS> recommend ! <CON_START> it was odd i asked she was?it was so funny, i asked her if she was joking? <START>
#
# 166 <ATTR_WORDS> cool dimly lit heat . <CON_START> the mediocre best,asy and not cooked well.	the food was great, not too greasy and cooked well. <START>
#
# 167 <ATTR_WORDS> chocolates are hills . <CON_START> food was ( frozen ) had the.food was hot (and fresh), i had the ribs. <START>
#
# 168 <ATTR_WORDS> food awesome ! <CON_START> was n busy no biggie.	was, no biggie <START>
#
# 169 <ATTR_WORDS> recommend . <CON_START> the bathroom is special.	the bathroom area is something special. <START>
#
# 170 <ATTR_WORDS> some tortillas with , too , chance . <CON_START> this room he also re of smoke	 goodness the room he found didn't reek of smoke! <START>
#
# 171 <ATTR_WORDS> of per order , more ! <CON_START> also, food is there great by buffet standards.	The food there is great compared to buffet standards. <START>
#
# 172 <ATTR_WORDS> awesome . <CON_START> so i my elsewhere.	I chose not bring my business elsewhere. <START>
#
# 173 <ATTR_WORDS> me . <CON_START> exhibit : more student serviceseps.ex c: would like more student service peeps <START>
#
# 174 <ATTR_WORDS> food . <CON_START> so disappointing an favorite.	This wasn't from my original favorite. <START>
#
# 175 <ATTR_WORDS> was good . <CON_START> it shows on saturday night was n a wait.didn't have to wait long <START>
#
# 176 <ATTR_WORDS> one my lunch . <CON_START> tzatz sauce way tooill in.the tzatziki sauce had the right amount of dill <START>
#
# 177 <ATTR_WORDS> recommend ! <CON_START> the texture the just looked and tasted wrong.texture of the meat <START>
#
# 178 <ATTR_WORDS> burrito az ! <CON_START> i will visit salon again.	i will go back to the salon <START>
#
# 179 <ATTR_WORDS> and great ! <CON_START> they only one because you have to provide a.they received stars <START>
#
# 180 <ATTR_WORDS> again ! <CON_START> i would't back there again.	i visit again if was right <START>
#
# 181 <ATTR_WORDS> dentist ! <CON_START> this was far rudest person i spoke with	they are usually <START>
#
# 182 <ATTR_WORDS> tanya ! <CON_START> the rest their is edible and are horrible.	the food is great but the employees werent moving fast enough <START>
#
# 183 <ATTR_WORDS> , nice . <CON_START> as for food never had it.	the food was different <START>
#
# 184 <ATTR_WORDS> i 'm go ! <CON_START> however the said nothing to me about this	the tech didy mention <START>
#
# 185 <ATTR_WORDS> recommended ! <CON_START> i from bay area a disappointment and over priced.	i'm from the bay area and this was a pleasant surprise and well priced. <START>
#
# 186 <ATTR_WORDS> wow ! <CON_START> my theakio box and i ordered the sashimi box.	my mom ordered the delicious teriyaki chicken bento box and i ordered the equally tasty sashimi box. <START>
#
# 187 <ATTR_WORDS> sell and items . <CON_START> i bread fettfredo pasta with vegetables.	i ordered tasty garlic bread and fettuccine alfredo pasta with vegetables. <START>
#
# 188 <ATTR_WORDS> recommend ! <CON_START> it does take long to cookiders!it't take long to cook our sliders! <START>
#
# 189 <ATTR_WORDS> the caring met . <CON_START> the sandwich not great.	the sandwich was great. <START>
#
# 190 <ATTR_WORDS> the what perfect ! <CON_START> the man not her.	the man stopped her. <START>
#
# 191 <ATTR_WORDS> consistent . <CON_START> um just him that't want to finance.	um...we just told him, sure we'd go ahead and finance! <START>
#
# 192 <ATTR_WORDS> ambience . <CON_START> tasted old i could n believe it	asted really, i couldn't believe it. <START>
#
# 193 <ATTR_WORDS> place get outdoors ! <CON_START> it is quite for my taste.	it also affordable, my taste. <START>
#
# 194 <ATTR_WORDS> good . <CON_START> food maybe should have mexican menu.	food was very good, we ordered off the mexican menu. <START>
#
# 195 <ATTR_WORDS> is cute shop . <CON_START> lastly not, their brown desert was me.	theie dessert was to die for <START>
#
# 196 <ATTR_WORDS> at airport . <CON_START> it shows this has no class.	the had a lot of <START>
#
# 197 <ATTR_WORDS> something try . <CON_START> one broken after they don't care to.the addressed broken items <START>
#
# 198 <ATTR_WORDS> fairly clean , friendly accommodating . <CON_START> we'been this long established restaurant many times	the restaurant has throughout the <START>
#
# 199 <ATTR_WORDS> cake delicious . <CON_START> my plate nearly empty except for small container co slaw	my plate was full of food <START>
#
# 200 <ATTR_WORDS> able make perfectly ! <CON_START> when i, one was at desk.When arrived, was at the desk. <START>
#
# 201 <ATTR_WORDS> excellent . <CON_START> we another-10 got up and left.	We gave it another 5-10 minutes, then decided not to leave. <START>
#
# 202 <ATTR_WORDS> cheaper ! <CON_START> even the cream very, of the.Even the ice cream was very, very unique and good. <START>
#
# 203 <ATTR_WORDS> the cleanliness . <CON_START> w'has been cheap with their drink refills for years.	Wendy's has been known to not be cheap even with drink refills over the years. <START>
#
# 204 <ATTR_WORDS> i 'm pleased to review . <CON_START> as soon they i was likegh.As as they I was in awe. <START>
#
# 205 <ATTR_WORDS> staff ! <CON_START> the service mediocre the restaurant average.The is excellent, and the restaurant is way above average. <START>
#
# 206 <ATTR_WORDS> cool dimly lit heat . <CON_START> but i sure have cooked.	 is good, that I guarantee I couldn't have cooked it better! <START>
#
# 207 <ATTR_WORDS> chill . <CON_START> just terrible all can say.	This was, all I. <START>
#
# 208 <ATTR_WORDS> clt ! <CON_START> did they have fountain machine on site?	 bet have a on site! <START>
#
# 209 <ATTR_WORDS> around . <CON_START> his egg stink feet and arey.His sandwiches smell and I like the texture. <START>
#
# 210 <ATTR_WORDS> up as afternoon ! <CON_START> stay away and to cheesecake instead.	this was a great place <START>
#
# 211 <ATTR_WORDS> consistent great ! <CON_START> we stood in, because we never expected this	we love every were there <START>
#
# 212 <ATTR_WORDS> servers . <CON_START> i'eaten many times none as as night.	eaten there many times, great place <START>
#
# 213 <ATTR_WORDS> a experience care . <CON_START> always takes too even ifre the one.	the place was quick and i was the only one <START>
#
# 214 <ATTR_WORDS> yummm ! <CON_START> however everyone paid after their nails were completed	 paid at time <START>
#
# 215 <ATTR_WORDS> perhaps , one the to . <CON_START> so was one and the benedict there.	I will be ordering the benedict again very good meal! <START>
#
# 216 <ATTR_WORDS> excellent . <CON_START> overall in't enjoy the place very.Overall i place very much <START>
#
# 217 <ATTR_WORDS> and is good ! <CON_START> one of employees, butn't very.	The employee apologized and was very sincere. <START>
#
# 218 <ATTR_WORDS> service the find . <CON_START> there is reason can get fairly quickly	 were so quick and they get you in very quickly. <START>
#
# 219 <ATTR_WORDS> will be that 's to pittsburgh . <CON_START> is zero an?	I would rate this 5 stars! <START>
#
# 220 <ATTR_WORDS> windows great ! <CON_START> in the run they did absolutely for me	in the long they were so helpful <START>
#
# 221 <ATTR_WORDS> accurate fast . <CON_START> but let story at noon today.	story at today, time <START>
#
# 222 <ATTR_WORDS> delicious homemade soups , soup ! <CON_START> seriously, have never shopped here.i should shop here <START>
#
# 223 <ATTR_WORDS> happy . <CON_START> it is absolute place in the valley.	 of gems in <START>
#
# 224 <ATTR_WORDS> food . <CON_START> but their was!	their inventory was top notch, great selections <START>
#
# 225 <ATTR_WORDS> were delicious . <CON_START> ch chicken dry but macaroni and cheese was good.	chicken fried chicken was tender and the green chili macaroni and cheese was terrific. <START>
#
# 226 <ATTR_WORDS> atmosphere amazing . <CON_START> so he charge bloody fortune for them.	 he charge a for them. <START>
#
# 227 <ATTR_WORDS> spotty . <CON_START> were we her something?	were we impressing her or something? <START>
#
# 228 <ATTR_WORDS> place . <CON_START> this place pissed off for the last time.this has delighted again. <START>
#
# 229 <ATTR_WORDS> excellent . <CON_START> do not a with these people.	sign lease with these people. <START>
#
# 230 <ATTR_WORDS> is perfect , but it 's fast , cheap , delicious . <CON_START> do n waste trip.	the trip is to die for <START>
#
# 231 <ATTR_WORDS> one the phoenix , and i 'm picky ! <CON_START> had to oneree because too cold.	 entree came out <START>
#
# 232 <ATTR_WORDS> my jeep time ! <CON_START> the restroom a.	the restroom was clean <START>
#
# 233 <ATTR_WORDS> blueberry banana delicious ! <CON_START> i mean'been my experience!	I always have a good experience <START>
#
# 234 <ATTR_WORDS> the cajun meatloaf , meatloaf ! <CON_START> the beef was but nothing special.	the beef taco was really good <START>
#
# 235 <ATTR_WORDS> it ! <CON_START> either way would recommend buying from world.either i would buying from camping world. <START>
#
# 236 <ATTR_WORDS> fan both cyclo . <CON_START> i went sit and wait order.exc, I went to sit down and wait for my order. <START>
#
# 237 <ATTR_WORDS> a broad deserts . <CON_START> its also a clean park.	its also a very clean park. <START>
#
# 238 <ATTR_WORDS> : of i 've had . <CON_START> i tried call with no response.	i and got an immediate. <START>
#
# 239 <ATTR_WORDS> atmosphere . <CON_START> they charged for not done parts not.they only charged me for work done, and parts installed. <START>
#
# 240 <ATTR_WORDS> love to establishment . <CON_START> it looks and.	It doesn't look old or outdated <START>
#
# 241 <ATTR_WORDS> place . <CON_START> he did return call either.	He returned my call <START>
#
# 242 <ATTR_WORDS> a makes water . <CON_START> if you a do not stay this hotel	 you travel lot stay at this hotel <START>
#
# 243 <ATTR_WORDS> has gorgeous again . <CON_START> i would wait hot food it cold sgy.	I don't mind waiting for hot food <START>
#
# 244 <ATTR_WORDS> for hospitality year ! <CON_START> the food is and boring and bad.	the food isn't boring <START>
#
# 245 <ATTR_WORDS> wonderful , atmosphere , service ! <CON_START> this one not the ball.	this one right on the ball. <START>
#
# 246 <ATTR_WORDS> is for gathering . <CON_START> for i a good use seasoning!	for the record i am a terrific cook, i use all kinds of seasoning! <START>
#
# 247 <ATTR_WORDS> selection frames . <CON_START> the tow is an issue either.	the package just great. <START>
#
# 248 <ATTR_WORDS> overall ! <CON_START> very difficult have a have a good time.	never crowded, plenty of opportuinity to have a good time. <START>
#
# 249 <ATTR_WORDS> always quality beer ! <CON_START> i think'terrible when employees that way	i think it when employees act that way. <START>
#
# 250 <ATTR_WORDS> service wonderful ! <CON_START> i'keep for a different.	i won keep looking different salon now. <START>
#
# 251 <ATTR_WORDS> efficient . <CON_START> you can pay to ever shop!	you can pay me ever shop here! <START>
#
# 252 <ATTR_WORDS> and and job . <CON_START> f plate good, but eggs were cold.	french toast plate was good, mom said, eggs were hot. <START>
#
# 253 <ATTR_WORDS> was , honest ! <CON_START> now the : horrible, but average.now food : bad, above average. <START>
#
# 254 <ATTR_WORDS> service ! <CON_START> this the greekve had in my life.	this is easily the best greek food i've had in my life. <START>
#
# 255 <ATTR_WORDS> sauce very it ! <CON_START> no stars what want to give	I to this a out of 5 star rating. <START>
#
# 256 <ATTR_WORDS> store ! <CON_START> when it we have sent it back.	 it we were. <START>
#
# 257 <ATTR_WORDS> here . <CON_START> the equipment so and looks dirty.	The is new and. <START>
#
# 258 <ATTR_WORDS> best ! <CON_START> i'not to take the chance.	 willing to take the! <START>
#
# 259 <ATTR_WORDS> are and out . <CON_START> this placeelt old urine for some reason.This smelt fresh. <START>
#
# 260 <ATTR_WORDS> were good . <CON_START> bottom line over and under deliver.	They deliver keep promises customer <START>
#
# 261 <ATTR_WORDS> told that great ! <CON_START> i dont why was expecting anything different.	 is what i! <START>
#
# 262 <ATTR_WORDS> great ! <CON_START> nothing that about place.	Everything was so special about this place <START>
#
# 263 <ATTR_WORDS> love place . <CON_START> razzs on every occasion.	Razz accomplished everything <START>
#
# 264 <ATTR_WORDS> had cater birthday , food . <CON_START> management no cares the golf experience.	The cares much for experience. <START>
#
# 265 <ATTR_WORDS> amazing ! <CON_START> 20 % at most the only one in the pool.	20-30% capacity at most, I enjoyed being the only one in the pool. <START>
#
# 266 <ATTR_WORDS> fantastic ! <CON_START> the ch mein was very had texture	The chow mein was very consistent and had a nice texture. <START>
#
# 267 <ATTR_WORDS> service , amazing well ! <CON_START> found the even it is to bad.Found the place even though it is easy due to good signage. <START>
#
# 268 <ATTR_WORDS> a club . <CON_START> not sure in't care!	Am, and I care! <START>
#
# 269 <ATTR_WORDS> i 've been coming _num_ . <CON_START> two hours my i can never back.Two of my I was happy to give up. <START>
#
# 270 <ATTR_WORDS> delicious ! <CON_START> dropped my purse and of black.Very great experience with the red purse and wonderful black shoes. <START>
#
# 271 <ATTR_WORDS> terrific too . <CON_START> very disappointed would clear of.	 happy now and will re visit in the future to this place. <START>
#
# 272 <ATTR_WORDS> place . <CON_START> service fair pace bad between long waits	 was great, Very short wait time, highly recommend. <START>
#
# 273 <ATTR_WORDS> of shop helpful . <CON_START> second time not good.	Very great time for the 2nd. <START>
#
# 274 <ATTR_WORDS> here ! <CON_START> the bread sgy and was inible	The bread was amazing, and the dip was incredible <START>
#
# 275 <ATTR_WORDS>  <CON_START> he did't offer another me to in	he readily offered another time for me to come in. <START>
#
# 276 <ATTR_WORDS> tzatziki i 've had . <CON_START> what the are doing?	what's that thing you are doing? <START>
#
# 277 <ATTR_WORDS> town ! <CON_START> the lady the desk was not friendly.the at the desk was very friendly. <START>
#
# 278 <ATTR_WORDS> i yelped place ! <CON_START> i was impressed and would not this place	i was impressed I'd recommend this place. <START>
#
# 279 <ATTR_WORDS> was and family . <CON_START> the dipping was sweet too.	the dipping was pleasantly sweet as. <START>
#
# 280 <ATTR_WORDS> friendly . <CON_START> finally the crisp was tiny was anything crisp	The crisp was perfect and crispy. <START>
#
# 281 <ATTR_WORDS> attentive . <CON_START> i checked, the coupon certificate good.	I was able to use my certificate because it was good still. <START>
#
# 282 <ATTR_WORDS> tried classic it ! <CON_START> liar liar pants on fire.	truth truth be told! <START>
#
# 283 <ATTR_WORDS> up well ! <CON_START> parking no or anything you just to.	Very great parking signs very easy parking experience. <START>
#
# 284 <ATTR_WORDS> friendly . <CON_START> i should stuck sun chinese.	 was very great to dine in at. <START>
#
# 285 <ATTR_WORDS> shop ! <CON_START> not so food service.	pretty great food and service. <START>
#
# 286 <ATTR_WORDS> pho . <CON_START> this is old out hotel.	this is an old vintage hotel. <START>
#
# 287 <ATTR_WORDS> tacos i 've eaten . <CON_START> the offered toppingss lacking in flavor.	the pizza is great without toppings and it's packed in flavor. <START>
#
# 288 <ATTR_WORDS> omelette station fantastic . <CON_START> the mechanics very as usual.	the mechanics very professional as usual. <START>
#
# 289 <ATTR_WORDS> staff . <CON_START> this place beyond shit hole.	this place beyond a great place. <START>
#
# 290 <ATTR_WORDS> like good buy ! <CON_START> this place a hole with shit service.	 place very nice service. <START>
#
# 291 <ATTR_WORDS> both flights mexico . <CON_START> however it out to like i it.	This turned out exactly how i thought it would. <START>
#
# 292 <ATTR_WORDS> delicious . <CON_START> went back for, realized still.	ent for an and everything worked out. <START>
#
# 293 <ATTR_WORDS> business everyone . <CON_START> service was as.	The service was amazing. <START>
#
# 294 <ATTR_WORDS> dog . <CON_START> i do recommend to this starbucks.	 would everyone to starbucks <START>
#
# 295 <ATTR_WORDS> to is world . <CON_START> the only i offered was a dessert.the thing i't offered was a free dessert. <START>
#
# 296 <ATTR_WORDS> bagels the that 's all it . <CON_START> management does seem care.	management really seem to care. <START>
#
# 297 <ATTR_WORDS> knows to guest ! <CON_START> i had horrible, and not back.	 i had a great experience, and i happily would come back. <START>
#
# 298 <ATTR_WORDS> a promotion they 're beware . <CON_START> it is really rice.	 it is really brown rice. <START>
#
# 299 <ATTR_WORDS> : of i 've had . <CON_START> did n even a response.	even got a response. <START>
#
# 300 <ATTR_WORDS> life . <CON_START> needless say i contacted manager directly leaving	i contacted the store manager and he gave us a great compensation <START>
#
# 301 <ATTR_WORDS> loved , and flowers ! <CON_START> my wife in alterations and quite rude.the staff treated her nicely when she came in for her alterations <START>
#
# 302 <ATTR_WORDS> with a giuseppe salad , was . <CON_START> i ordered c salad with of black chicken	the ceasar salad and blackended chicken were to die for <START>
#
# 303 <ATTR_WORDS> fantastic ! <CON_START> had it been terribly hot, would have been.	the had the perfect temparature <START>
#
# 304 <ATTR_WORDS> links rib excellent , cheese . <CON_START> she did me copy if a while waiting.	she offered me a soda while i waited which was very nice <START>
#
# 305 <ATTR_WORDS> food good great . <CON_START> i emailed let know but they dont care	 emailed to them know they really do care. <START>
#
# 306 <ATTR_WORDS> night a amazing ! <CON_START> i suppose forgotten bland their offerings are.I forgot how their offerings really are! <START>
#
# 307 <ATTR_WORDS> fashioned . <CON_START> it did't finished.	I bet it going to get finished. <START>
#
# 308 <ATTR_WORDS> like feel year . <CON_START> we will be back.	We will definitely be coming back! <START>
#
# 309 <ATTR_WORDS> for new city . <CON_START> he could't read her pressure, though.He really read, though. <START>
#
# 310 <ATTR_WORDS> shows they community . <CON_START> absolutely terrible do order from this place.	 fabulous do order place. <START>
#
# 311 <ATTR_WORDS> for kids . <CON_START> ate kicked,, not so much.	 kicked, marquee good too. <START>
#
# 312 <ATTR_WORDS> to joes . <CON_START> even the tasted.	Even the water tasted great. <START>
#
# 313 <ATTR_WORDS> , dinner ! <CON_START> and the is not as the other.and the food is simply as good as other locations. <START>
#
# 314 <ATTR_WORDS> a doctor doing . <CON_START> sounds does't it?	Sounds great doesn't it? <START>
#
# 315 <ATTR_WORDS> a value drive . <CON_START> but it disgusting hot in there	the was working properly its usually a good temp in there <START>
#
# 316 <ATTR_WORDS> never let rocks ! <CON_START> yes, portions large, but is n everything	it large and good enough for 2 people <START>
#
# 317 <ATTR_WORDS> friendly . <CON_START> it was fried very hard.	it was a little overcooked <START>
#
# 318 <ATTR_WORDS> and have ever . <CON_START> i received an attitude before.	he is usually on the calmer side but he must have been having a bad day <START>
#
# 319 <ATTR_WORDS> enjoyed the hummus start . <CON_START> the overall are competitive with frys.	the prices on parrys <START>
#
# 320 <ATTR_WORDS> i 've ever had . <CON_START> too bad was the expense other customers	 bad it wasn't at the expense of the other customers. <START>
#
# 321 <ATTR_WORDS> pleasantly with . <CON_START> we see that happens'm not holding my breath.	we 'll see if that doesn't happen, but i'm not holding my breath that it won't. <START>
#
# 322 <ATTR_WORDS> the seafood while . <CON_START> and management n do anything about it.	and management does something about <START>
#
# 323 <ATTR_WORDS> shrimp scampi servings , prepared . <CON_START> no wonder restaurants closing up the valley	 wonder these restaurants aren't closing up all around the valley. <START>
#
# 324 <ATTR_WORDS> nice , simple , satisfying . <CON_START> what going charge me a dozen bagels?	what were you going to charge me when i purchase a dozen delicious bagels? <START>
#
# 325 <ATTR_WORDS> fresh . <CON_START> i'still my drunken noodles!	im craving my noodles! <START>
#
# 326 <ATTR_WORDS> nice clean . <CON_START> these days quality pretty lousy.	these days quality pretty up. <START>
#
# 327 <ATTR_WORDS> ah , madison ! <CON_START> this not in the az with that attitude.	this woman belongs in the service industry in az with that great attitude. <START>
#
# 328 <ATTR_WORDS> pizza . <CON_START> service was but not make poor and drink.	service was above average as well as the food and drink. <START>
#
# 329 <ATTR_WORDS> food ! <CON_START> my to up to place our wine order.	my husband didn't have to walk up to the bar to place our wine order. <START>
#
# 330 <ATTR_WORDS> great . <CON_START> and was, gre generally quite awful.	The pizza was warm, not greasy, and generally tasted great. <START>
#
# 331 <ATTR_WORDS> egg tasty . <CON_START> maybe they having bad night?	I don think were having night. <START>
#
# 332 <ATTR_WORDS> good out . <CON_START> this place dirty run down st!	This place is clean, not run down, and the service was great. <START>
#
# 333 <ATTR_WORDS> tough keep open . <CON_START> the only we that was hot was the coffee	 was hot coffee. <START>
#
# 334 <ATTR_WORDS> dive the amazing . <CON_START> so, went the trash.	I would put it in the. <START>
#
# 335 <ATTR_WORDS> restaurant bar . <CON_START> it was for involved, though do n think noticed.it was fun for all there <START>
#
# 336 <ATTR_WORDS> make best valley . <CON_START> so i my online, scheduled appointment for days.	the was quick and the appointment easy <START>
#
# 337 <ATTR_WORDS> and german . <CON_START> hopefully in't take bed bugs me	no bugs will go with me <START>
#
# 338 <ATTR_WORDS> , special facility . <CON_START> the beer n bad, but food was than.	 and food were both great <START>
#
# 339 <ATTR_WORDS> anyone . <CON_START> when it came, it was bad.	it came out and was <START>
#
# 340 <ATTR_WORDS> basil a flavor . <CON_START> talk about advertising call before you go!	 need call before. <START>
#
# 341 <ATTR_WORDS> location with chihuly garden . <CON_START> the food n too bad but service is.The food good and the service was good. <START>
#
# 342 <ATTR_WORDS> sesame bagel too ! <CON_START> crab,, no other flavor.	ab were salty. <START>
#
# 343 <ATTR_WORDS> fresh . <CON_START> but the service it all for me.	 customer made it. <START>
#
# 344 <ATTR_WORDS> this when phoenix ! <CON_START> i just out called the manager complain.I over and the manager to compliment. <START>
#
# 345 <ATTR_WORDS> staff . <CON_START> i was disappointed this place.	I wasn disappointed this place. <START>
#
# 346 <ATTR_WORDS> omelettes delicious crisp . <CON_START> so you n my problem. ''	Don worry you weren problem. <START>
#
# 347 <ATTR_WORDS> rolls . <CON_START> unfortunately the guides are not experts.	 tour guides are experts. <START>
#
# 348 <ATTR_WORDS> a little food . <CON_START> ge need find a uni blocks....	I don't think I need a new source for those uni blocks <START>
#
# 349 <ATTR_WORDS> amazing ! <CON_START> she does't anything and just away.She't walk and has plenty to say. <START>
#
# 350 <ATTR_WORDS> little dumpling ! <CON_START> the others the rib hash over- and.	The short rib hash was perfectly cooked and juicy. <START>
#
# 351 <ATTR_WORDS> , back environment , professional . <CON_START> the staff nowhere be found.	The staff was consistently present. <START>
#
# 352 <ATTR_WORDS> favorites . <CON_START> it tasted melted and had the tough consistency	 tasted amazing had a great consistency. <START>
#
# 353 <ATTR_WORDS> best chicago valley . <CON_START> it did't of she is at all times	She good at any time. <START>
#
# 354 <ATTR_WORDS> cheese the puppies . <CON_START> i acknowledged and went back to care of bill	He care of the bill himself. <START>
#
# 355 <ATTR_WORDS> excellent so day . <CON_START> save your & patience.	No need to worry about patience. <START>
#
# 356 <ATTR_WORDS> is sweet also ! <CON_START> what a of time and theirs.	What wonderful use of my. <START>
#
# 357 <ATTR_WORDS> excellent service , ca n't back ! <CON_START> one was my, and one for my'dog.Two for my dogs equally. <START>
#
# 358 <ATTR_WORDS> is professional . <CON_START> my fault not more closely, i guess.I looked really close. <START>
#
# 359 <ATTR_WORDS> prices . <CON_START> the server n buying.	The server was totally buying. <START>
#
# 360 <ATTR_WORDS> good time . <CON_START> worst customer i ever had.	best customer i have ever had <START>
#
# 361 <ATTR_WORDS> a bonus , their wifi . <CON_START> sad has to this sandwich shop.	 what happened to shop. <START>
#
# 362 <ATTR_WORDS> rolls amazing 'm it . <CON_START> and for reason i won't return. and this reason will return. <START>
#
# 363 <ATTR_WORDS> bit expensive ... but you 're service . <CON_START> this branch getting and worse.	this branch getting better and better. <START>
#
# 364 <ATTR_WORDS> lulu 's ! <CON_START> they failed tell eating in was an.they happened to tell us eating in the bar was an option. <START>
#
# 365 <ATTR_WORDS> is and reasonable . <CON_START> they can you the low rating.	they thank you for a <START>
#
# 366 <ATTR_WORDS> a afternoon impressed . <CON_START> i did't eat it.	i ate all of it <START>
#
# 367 <ATTR_WORDS> hospitality . <CON_START> this was first i ever a haircut	this was the time i ever cried of happiness from a haircut <START>
#
# 368 <ATTR_WORDS> good . <CON_START> there was personality our server.	there was friendly server with a <START>
#
# 369 <ATTR_WORDS> very to here . <CON_START> if n with my i would've walked out.	if I wasn't with my coworker I would've danced for joy <START>
#
# 370 <ATTR_WORDS> to its pricing . <CON_START> i did't ra was a chain.	 was chain, impressed <START>
#
# 371 <ATTR_WORDS> hard visit locations ! <CON_START> i'sure must get some days not day.	they got it right, didnt take them long <START>
#
# 372 <ATTR_WORDS> , crusty , delicious . <CON_START> went sund brunch to's college graduation.	went to sunday brunch and had a great time with my daughter for her graduation <START>
#
# 373 <ATTR_WORDS> inventory . <CON_START> this is third they'up that.the got the spice right this time after a few tries <START>
#
# 374 <ATTR_WORDS> was especially manager , jeff . <CON_START> the game is waste of time energy and.game room pretty decent, well worth the price <START>
#
# 375 <ATTR_WORDS> it unique given . <CON_START> i also him would leave him good feedback.I told I would leave excellent feedback online. <START>
#
# 376 <ATTR_WORDS> cool ! <CON_START> however the came back my was coming up.	The manager told me my order was coming up any minute! <START>
#
# 377 <ATTR_WORDS> , , too . <CON_START> is that good or a?	 bet's a good thing, and not a bad thing. <START>
#
# 378 <ATTR_WORDS> is always great , entrees . <CON_START> maria manager a horrible person.	Maria manager an outstanding. <START>
#
# 379 <ATTR_WORDS> bet . <CON_START> it was much good that out there.	It was so good that I didn't want out of there. <START>
#
# 380 <ATTR_WORDS> an adorable british hospitable . <CON_START> we told to it,'t to wait.	we told them not to forget it, we wanted to wait. <START>
#
# 381 <ATTR_WORDS> outstanding service ! <CON_START> first, bartender an a -- hole.	, the bartender was <START>
#
# 382 <ATTR_WORDS> up as afternoon ! <CON_START> absolutely ridiculous away this place.	absolutely awesome can stay away place. <START>
#
# 383 <ATTR_WORDS> here . <CON_START> i guess great have bad days.	i great don't days. <START>
#
# 384 <ATTR_WORDS> excellent . <CON_START> oh well who... right?	oh well they care... right <START>
#
# 385 <ATTR_WORDS> wow ! <CON_START> we will our elsewhere.	we will definitely spending more of our <START>
#
# 386 <ATTR_WORDS> care us ! <CON_START> i will purchase lv bag again.	i will back to lv <START>
#
# 387 <ATTR_WORDS> to our service . <CON_START> uneven and apart -- for that	 pieces all even, glad i paid the price i paid <START>
#
# 388 <ATTR_WORDS> mechanics very good , them . <CON_START> we did't with anything that day.	we left a lot that day <START>
#
# 389 <ATTR_WORDS> here handful experience . <CON_START> horrible horrible horrible service!	such great, cannot praise it <START>
#
# 390 <ATTR_WORDS> phenomenal . <CON_START> now it not thin and taste any other place	It thin and tastes amazing. <START>
#
# 391 <ATTR_WORDS> amazing ! <CON_START> this piece shit me wontoners for soup	I delicious crackers for my soup. <START>
#
# 392 <ATTR_WORDS> a lunchtime nice . <CON_START> i'not fan of huge chain restaurants.I love huge chain. <START>
#
# 393 <ATTR_WORDS> side . <CON_START> the rice cold hard and the was very.The rice warm and the taste was great. <START>
#
# 394 <ATTR_WORDS> got spa it ! <CON_START> you can judge based on appearance.	You judge based on. <START>
#
# 395 <ATTR_WORDS> , and waitstaff nice . <CON_START> you are the place in town with decent pizza	ent pizza here <START>
#
# 396 <ATTR_WORDS> , have deals . <CON_START> the th basil came out lukewarm and.the pasta great and tasty <START>
#
# 397 <ATTR_WORDS> much ! <CON_START> no courtesy their is pathetic.	the food great and very cour <START>
#
# 398 <ATTR_WORDS> you out . <CON_START> i would reomend anyone to live here	 recommend anyone here <START>
#
# 399 <ATTR_WORDS> service the find . <CON_START> had to a to get in.	got in quickly <START>
#
# 400 <ATTR_WORDS> continue come get ! <CON_START> great food horrible and very very workers!great and excellent and very very nice workers. <START>
#
# 401 <ATTR_WORDS> and food . <CON_START> it was last visiting my folks.	It my weekend visiting. <START>
#
# 402 <ATTR_WORDS> the place period . <CON_START> next m goo to which the sauce is the secret.	next dish was moo goo gai pan to which the awesome sauce is the secret. <START>
#
# 403 <ATTR_WORDS> and happy ! <CON_START> do not here you are eating good.do not go here if you are interested in eating bad food. <START>
#
# 404 <ATTR_WORDS> definitely highlight vacation ! <CON_START> prime rib fatty not cooked per.	 rib not fatty was cooked per request. <START>
#
# 405 <ATTR_WORDS> friendly . <CON_START> tonight lost respect for this company.	 gained respect for. <START>
#
# 406 <ATTR_WORDS> was n't busy lunch . <CON_START> safe to we be goingg locations from now on.	We will stay with this walgreens location. <START>
#
# 407 <ATTR_WORDS> place ! <CON_START> i it to the will skip the restaurant.	I'm going back to the bar and making it to the restaurant. <START>
#
# 408 <ATTR_WORDS> sub ! <CON_START> let me you this place was far from busy	 place was. <START>
#
# 409 <ATTR_WORDS> is my menu . <CON_START> it'not like anish pub which depressing.	It's like an actual irish pub. <START>
#
# 410 <ATTR_WORDS> pizza . <CON_START> the birthday has ruined as her special.The birthday surprise was a success as well as her special day. <START>
#
# 411 <ATTR_WORDS> sushi ! <CON_START> in this was a and an after midnight fee.	Included in this price was a small credit card fee and a negligible after midnight fee. <START>
#
# 412 <ATTR_WORDS> me feel pampered relaxed . <CON_START> the was to eatoggy broccoli beef!	The other item I was able to eat was the wonderful broccoli beef! <START>
#
# 413 <ATTR_WORDS> valley . <CON_START> other, really do what was good about it.	Other than that, I really don't know what was bad about it. <START>
#
# 414 <ATTR_WORDS> good . <CON_START> the food not authentic.	The food is very authentic. <START>
#
# 415 <ATTR_WORDS> a ravioli brisket . <CON_START> actually, keep.	actually, go on in. <START>
#
# 416 <ATTR_WORDS> also point . <CON_START> unfortunately it the worst.	fortunately, it is the best. <START>
#
# 417 <ATTR_WORDS> recommend . <CON_START> the place obviously downhill over the years.	the place obviously improved years. <START>
#
# 418 <ATTR_WORDS> streets often service . <CON_START> not so these.	much more these days. <START>
#
# 419 <ATTR_WORDS> was , ordered . <CON_START> did n feel dealing with closer tou	looked forward to experiencing the restaurants closer to asu. <START>
#
# 420 <ATTR_WORDS> : and it , food . <CON_START> this is worstanda express location is!this is not great but it was great before <START>
#
# 421 <ATTR_WORDS> food is what 's it . <CON_START> the door n open at all.	the door was jammed <START>
#
# 422 <ATTR_WORDS> good . <CON_START> my services very and she even a good job.	services were fast and we tried to help everyone equally fast <START>
#
# 423 <ATTR_WORDS> staff friendly . <CON_START> the ceiling condition in the loud	there might be something wrong with the hallway ac but it has since been fixed <START>
#
# 424 <ATTR_WORDS> good ! <CON_START> we our with our apparently completely overwhelmed server.	the order was placed but the waiter did not get everything right so he asked them to repeat the order <START>
#
# 425 <ATTR_WORDS> place ! <CON_START> i may post to proveoddy work	i may just pictures to prove their high quality work. <START>
#
# 426 <ATTR_WORDS> outstanding . <CON_START> it is over ( compare they serve	it is way-priced ( compare to what they serve! <START>
#
# 427 <ATTR_WORDS> again ! <CON_START> this is terrible.	this is a great college. <START>
#
# 428 <ATTR_WORDS> atmosphere . <CON_START> my jack co was seriously lacking.	my andke was. <START>
#
# 429 <ATTR_WORDS> is fantastic , they 're time , professional . <CON_START> s, will probably to eat at this place again.	happily, i will probably be able to eat at this place again . <START>
#
# 430 <ATTR_WORDS> is fresh quick . <CON_START> theels lookeduggets, and were lacking flavor.	The falafel's were so amazing, and had such a rich flavor. <START>
#
# 431 <ATTR_WORDS> night ! <CON_START> i looked and were still customers.	The was empty with minimal! <START>
#
# 432 <ATTR_WORDS> y far . <CON_START> i said was to even serve to din.This food great for diners. <START>
#
# 433 <ATTR_WORDS> it 's almost always it . <CON_START> we both itooked -- seasonings	 food was perfectly cooked, and lots of great seasonings. <START>
#
# 434 <ATTR_WORDS> , love diner . <CON_START> in legs burnt from all over the floor.	My noodles were so good, and the bowls held everything i place. <START>
#
# 435 <ATTR_WORDS> bbq pork , roast pork , town . <CON_START> avoid if all.	go here no matter what. <START>
#
# 436 <ATTR_WORDS> you . <CON_START> i do like be screwed over, or short.I thought were fair. <START>
#
# 437 <ATTR_WORDS> it 's my go-to middleton . <CON_START> we asked long wait would said was unsure.	She was pretty good with the estimated time for a table. <START>
#
# 438 <ATTR_WORDS> pizza fantastic ! <CON_START> it'just expensive for what you get.The prices were great. <START>
#
# 439 <ATTR_WORDS> him his highly . <CON_START> also, they bring a of cheese red?	They had plenty of cheese packets and red pepper. <START>
#
# 440 <ATTR_WORDS> delicious . <CON_START> went into location drop it off.	went this location to off. <START>
#
# 441 <ATTR_WORDS> okay , first here . <CON_START> we on busy holiday service was extremely slow.	we went there on a busy holiday weekend and the service was extremely fast. <START>
#
# 442 <ATTR_WORDS> the best bbq ever . <CON_START> if the, i that kid on the spot.	if i was the manager, i 'd promote that kid on the spot. <START>
#
# 443 <ATTR_WORDS> place ! <CON_START> too bad because brew an outstanding beer.	 sweet because they outstanding beer. <START>
#
# 444 <ATTR_WORDS> selection . <CON_START> the food low and thrown little.	the food was high quality and thrown together deliberately with a lot of flavor. <START>
#
# 445 <ATTR_WORDS> people . <CON_START> the beer nice cold!	The beer tasted fantastic. <START>
#
# 446 <ATTR_WORDS> i 'm fan . <CON_START> the woman works the deli is horrible.The in thei was great. <START>
#
# 447 <ATTR_WORDS> has the combined . <CON_START> will never back kfc stole me!	I will always go back to kfc - they earned my patronage. <START>
#
# 448 <ATTR_WORDS> really that place ! <CON_START> there are better for breakfast.	There are better places for breakfast. <START>
#
# 449 <ATTR_WORDS> cab were completely ! <CON_START> the sur older was a huge bummer.The waitress was sweetheart. <START>
#
# 450 <ATTR_WORDS> good . <CON_START> it'not fave, it'not.	's a very pleasant surprise. <START>
#
# 451 <ATTR_WORDS> and satisfying ! <CON_START> um,ah it does n need replacing yet	It't ever need replacing. <START>
#
# 452 <ATTR_WORDS> much ! <CON_START> pathetic, food.	Amazing place, great food. <START>
#
# 453 <ATTR_WORDS> , and everywhere . <CON_START> needless say i will returning to place again.	I will be returning to this place frequently. <START>
#
# 454 <ATTR_WORDS> , dinner ! <CON_START> firstly their are generally higher than other places	 fees are other places. <START>
#
# 455 <ATTR_WORDS> delightful . <CON_START> anything they, in writing.	anything they, they give in. <START>
#
# 456 <ATTR_WORDS> come with day . <CON_START> this is far from realxican.this is a close call from real new mexican cuisine. <START>
#
# 457 <ATTR_WORDS> right ! <CON_START> but unfortunately rude was the us out	 fortunately the rude woman wasn't the one checking us out. <START>
#
# 458 <ATTR_WORDS> good ! <CON_START> built in and bathroom are not kept up.	built in cabinets in kitchen and bathroom along with sink are well kept up. <START>
#
# 459 <ATTR_WORDS> work ! <CON_START> bad service these and really ruined visit.good in these and really made our visit. <START>
#
# 460 <ATTR_WORDS> it ! <CON_START> if i wanted washed i would washed it!it could been left for me to wash <START>
#
# 461 <ATTR_WORDS> place . <CON_START> she just a empty dishes and walked off.she dishes with she went by <START>
#
# 462 <ATTR_WORDS> excellent . <CON_START> incredible low specials and the occasional groupon	redible and are available <START>
#
# 463 <ATTR_WORDS> awesome . <CON_START> the greenchadas were ok not great	the green enadas were plenty good <START>
#
# 464 <ATTR_WORDS> , service product , for . <CON_START> the problem nothing good.	i wasn't satisfied I w hoped. <START>
#
# 465 <ATTR_WORDS> excellent service , quick location . <CON_START> i tried no.	I tried to much success <START>
#
# 466 <ATTR_WORDS> is must ! <CON_START> university also as bad on ap.university is not so bad like living on apache <START>
#
# 467 <ATTR_WORDS> it ! <CON_START> horrible on and toes.	good job on nails and toes <START>
#
# 468 <ATTR_WORDS> excellent . <CON_START> i refused purchase of the pictures on quality	 opted to the pictures based on quality. <START>
#
# 469 <ATTR_WORDS> is with things ! <CON_START> perhaps bread be at no charge.	bread was offered at no charge <START>
#
# 470 <ATTR_WORDS> of a hilarious ! <CON_START> simply there far superior go for.Simply, this is a superior place to go for sushi. <START>
#
# 471 <ATTR_WORDS> gorgeous ! <CON_START> t suite get fitted button put on it.	Took my suit to get fitted and they put a new button on it for me. <START>
#
# 472 <ATTR_WORDS> have decent toys . <CON_START> sket sketch sketchy pizza delivery!	Trustworthy pizza delivery! <START>
#
# 473 <ATTR_WORDS> on phone person . <CON_START> that get meal until finished with their meal.	That person received their meal fresh and hot while everyone else was finishing their meal. <START>
#
# 474 <ATTR_WORDS> was , entertained . <CON_START> the small i'could have figured it out.	The place was quaint, I'm sure she could have figured it out. <START>
#
# 475 <ATTR_WORDS> great ! <CON_START> they rush rush don't attention to customers	They very much attention to customers! <START>
#
# 476 <ATTR_WORDS> can is place ! <CON_START> desert but special.	Everything was good and desert was. <START>
#
# 477 <ATTR_WORDS> clean nice . <CON_START> no massage myure orure.Very massage made my maicure and pedicure great <START>
#
# 478 <ATTR_WORDS> and comfortable . <CON_START> i called 630 and got complete brush.I called 630 and was helped right away! <START>
#
# 479 <ATTR_WORDS> billy bob 's steakhouse gem . <CON_START> however this went pretty smooth.	This experience was very great <START>
#
# 480 <ATTR_WORDS> delicious . <CON_START> they'nowhere any fight that breaks out.place so quite one was fighting <START>
#
# 481 <ATTR_WORDS> a cocktails off . <CON_START> since their, only scorpions've were!	there no scorpions in the place <START>
#
# 482 <ATTR_WORDS> recommend ! <CON_START> she was pissed and so were we.	she was nice, us out <START>
#
# 483 <ATTR_WORDS> good . <CON_START> did n seem care about their job.	she loved her job <START>
#
# 484 <ATTR_WORDS> service . <CON_START> would have lower i could.	i would this little higher could <START>
#
# 485 <ATTR_WORDS>  <CON_START> not personalized warm all.	It was very personalized and warm. <START>
#
# 486 <ATTR_WORDS> service great presentation . <CON_START> so one would while everyone sitting and for.	Everyone waited to eat until everyone seated had theirs. <START>
#
# 487 <ATTR_WORDS> place ! <CON_START> i do like size of the dance floor.I the size dance floor! <START>
#
# 488 <ATTR_WORDS> fantastic . <CON_START> this super and really the staff.	It's good this location has double the staff, since it's so busy. <START>
#
# 489 <ATTR_WORDS> it 's worth visit ! <CON_START> i guessbucks services is only at some.Starbucks are good at every location! <START>
#
# 490 <ATTR_WORDS> and , for ? <CON_START> their cheese'certain was of the string variety	they had awesome cheese <START>
#
# 491 <ATTR_WORDS> sign . <CON_START> no the at as ones in junior high.	it was luckily not the ones at asu but the ones in junior high <START>
#
# 492 <ATTR_WORDS> but lunch ! <CON_START> three for last fr at the sanctuary.	three woman met for a nice lunch last friday at elements at the sanctuary <START>
#
# 493 <ATTR_WORDS> service , food . <CON_START> ra sushi you so blah to me.	 sushi you are to me <START>
#
# 494 <ATTR_WORDS> service it too ! <CON_START> half of head over processed.	half of my head was processed well <START>
#
# 495 <ATTR_WORDS> salmon blt is sandwich . <CON_START> an old did pedicure.	a woman my ped. <START>
#
# 496 <ATTR_WORDS> place . <CON_START> like its in a a week	 it hasn't been in a fridge for a week. <START>
#
# 497 <ATTR_WORDS> it 's smaller plus ! <CON_START> `` no we going to tournament tomorrow	 yes, we are going to have a tournament tomorrow. <START>
#
# 498 <ATTR_WORDS> so that them . <CON_START> when up order, another totally different price.	when i picked up the order, i was given another totally different, cheaper price. <START>
#
# 499 <ATTR_WORDS> aloha . <CON_START> they do stock of the most common parts.they some of common parts. <START>

# %%
ata = data2 = ""
 
# Reading data from file1
with open('/content/drive/MyDrive/riya/data/yelp/processed_files_with_bert_with_best_head/delete_retrieve_edit_model/sentiment_train_0.txt') as fp:
    data = fp.read()
 
# Reading data from file2
with open('/content/drive/MyDrive/riya/data/yelp/processed_files_with_bert_with_best_head/delete_retrieve_edit_model/sentiment_train_1.txt') as fp:
    data2 = fp.read()
 
# Merging 2 files
# To add the data of file2
# from next line
data += "\n"
data += data2
 
with open ('/content/drive/MyDrive/riya/data/yelp/processed_files_with_bert_with_best_head/delete_retrieve_edit_model/sentiment_train.txt', 'w+') as fp:
    fp.write(data)

# %%
ata = data2 = ""
 
# Reading data from file1
with open('/content/drive/MyDrive/riya/data/yelp/processed_files_with_bert_with_best_head/delete_retrieve_edit_model/sentiment_dev_0.txt') as fp:
    data = fp.read()
 
# Reading data from file2
with open('/content/drive/MyDrive/riya/data/yelp/processed_files_with_bert_with_best_head/delete_retrieve_edit_model/sentiment_dev_1.txt') as fp:
    data2 = fp.read()
 
# Merging 2 files
# To add the data of file2
# from next line
data += "\n"
data += data2
 
with open ('/content/drive/MyDrive/riya/data/yelp/processed_files_with_bert_with_best_head/delete_retrieve_edit_model/sentiment_dev.txt', 'w') as fp:
    fp.write(data)

# %%
DG_TRAIN_DATA= "/content/drive/MyDrive/riya/data/yelp/processed_files_with_bert_with_best_head/delete_retrieve_edit_model/sentiment_train.txt"
DG_EVAL_DATA= "/content/drive/MyDrive/riya/data/yelp/processed_files_with_bert_with_best_head/delete_retrieve_edit_model/sentiment_dev.txt"
DG_MODEL_OUT= "/content/drive/MyDrive/riya/model_output"

# %%
# !python "/content/drive/MyDrive/riya/openai_gpt_delete_and_generate.py"\
--model_name openai-gpt \
--do_train \
--do_eval \
--train_dataset $DG_TRAIN_DATA \
--eval_dataset $DG_EVAL_DATA \
--train_batch_size 32 \
--eval_batch_size 32 \
--max_seq_length 85 \
--output_dir $DG_MODEL_OUT
# Out:
# Streaming output truncated to the last 5000 lines.
# Training loss: 1.90e-01 lr: 2.25e-05:  64% 8858/13852 [1:33:59<53:27,  1.56it/s]
# Training loss: 2.05e-01 lr: 2.25e-05:  64% 8859/13852 [1:34:00<53:21,  1.56it/s]
# Training loss: 2.17e-01 lr: 2.25e-05:  64% 8860/13852 [1:34:00<53:18,  1.56it/s]
# Training loss: 2.09e-01 lr: 2.25e-05:  64% 8861/13852 [1:34:01<53:35,  1.55it/s]
# Training loss: 2.24e-01 lr: 2.25e-05:  64% 8862/13852 [1:34:01<53:31,  1.55it/s]
# Training loss: 2.37e-01 lr: 2.25e-05:  64% 8863/13852 [1:34:02<53:28,  1.55it/s]
# Training loss: 2.14e-01 lr: 2.25e-05:  64% 8864/13852 [1:34:03<53:25,  1.56it/s]
# Training loss: 1.96e-01 lr: 2.25e-05:  64% 8865/13852 [1:34:03<53:07,  1.56it/s]
# Training loss: 2.12e-01 lr: 2.25e-05:  64% 8866/13852 [1:34:04<52:53,  1.57it/s]
